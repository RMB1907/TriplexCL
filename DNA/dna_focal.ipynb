# %%
import imports
import split, model, weights, focal_train

# %%
import numpy as np

X = np.load("input/X.npy")
y = np.load("input/y.npy")

print(X.shape)  # (N, 90, 1)
print(y.shape)  # (N,)
# Out:
# (15272, 90, 1)
# (15272,)

# %%
X_train, X_val, X_test, y_train, y_val, y_test = split.stratified_split(X, y)

print("Train:", X_train.shape, y_train.shape)
print("Val:  ", X_val.shape, y_val.shape)
print("Test: ", X_test.shape, y_test.shape)
# Out:
# Train: (9773, 90, 1) (9773,)
# Val:   (2444, 90, 1) (2444,)
# Test:  (3055, 90, 1) (3055,)

# %%
print("Train class distribution:", np.bincount(y_train.astype(int)))
print("Val class distribution:", np.bincount(y_val.astype(int)))
print("Test class distribution:", np.bincount(y_test.astype(int)))
# Out:
# Train class distribution: [8149 1624]
# Val class distribution: [2038  406]
# Test class distribution: [2548  507]

# %%
print(y_train.shape)
# Out:
# (9773,)

# %%
import importlib
import model
importlib.reload(model)
# Out:
# <module 'model' from '/home/jupyter-22wh1a12a2/major_project/DNA/model.py'>

# %%
from model import build_model, compile_focal

model1 = build_model()
model = compile_focal(
    model1,
    alpha=0.75,
    gamma=2.0
)
model1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 90, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 90, 32)    │        128 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 90, 32)    │        192 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 90, 32)    │        256 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 90, 96)    │          0 │ conv1d_3[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_4[0][0],   │
# │                     │                   │            │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 45, 96)    │          0 │ concatenate_1[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     41,216 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      4,160 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 46,017 (179.75 KB)
#  Trainable params: 46,017 (179.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = focal_train.train_model(model1, X_train, y_train, X_val, y_val)
# Out:
# Epoch 1/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0566 - pr_auc: 0.1760 - precision_1: 0.2210 - recall_1: 0.0038 - roc_auc: 0.5155
# Epoch 1: val_pr_auc improved from None to 0.25710, saving model to output/dna_focal.keras
#
# Epoch 1: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 0.0569 - pr_auc: 0.1792 - precision_1: 0.3571 - recall_1: 0.0031 - roc_auc: 0.5165 - val_loss: 0.0547 - val_pr_auc: 0.2571 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_roc_auc: 0.6527 - learning_rate: 0.0010
# Epoch 2/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0539 - pr_auc: 0.2294 - precision_1: 0.2844 - recall_1: 0.1140 - roc_auc: 0.6177
# Epoch 2: val_pr_auc improved from 0.25710 to 0.44554, saving model to output/dna_focal.keras
#
# Epoch 2: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0533 - pr_auc: 0.2783 - precision_1: 0.3083 - recall_1: 0.2759 - roc_auc: 0.6745 - val_loss: 0.0458 - val_pr_auc: 0.4455 - val_precision_1: 0.3284 - val_recall_1: 0.7685 - val_roc_auc: 0.7965 - learning_rate: 0.0010
# Epoch 3/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0487 - pr_auc: 0.4130 - precision_1: 0.3680 - recall_1: 0.5887 - roc_auc: 0.7688
# Epoch 3: val_pr_auc improved from 0.44554 to 0.57649, saving model to output/dna_focal.keras
#
# Epoch 3: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0469 - pr_auc: 0.4521 - precision_1: 0.3957 - recall_1: 0.5406 - roc_auc: 0.7811 - val_loss: 0.0451 - val_pr_auc: 0.5765 - val_precision_1: 0.7681 - val_recall_1: 0.2611 - val_roc_auc: 0.8368 - learning_rate: 0.0010
# Epoch 4/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0451 - pr_auc: 0.4986 - precision_1: 0.4680 - recall_1: 0.6007 - roc_auc: 0.8144
# Epoch 4: val_pr_auc improved from 0.57649 to 0.58209, saving model to output/dna_focal.keras
#
# Epoch 4: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0444 - pr_auc: 0.5069 - precision_1: 0.4737 - recall_1: 0.6096 - roc_auc: 0.8163 - val_loss: 0.0438 - val_pr_auc: 0.5821 - val_precision_1: 0.6426 - val_recall_1: 0.4384 - val_roc_auc: 0.8569 - learning_rate: 0.0010
# Epoch 5/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0443 - pr_auc: 0.5173 - precision_1: 0.4758 - recall_1: 0.5997 - roc_auc: 0.8188
# Epoch 5: val_pr_auc improved from 0.58209 to 0.59076, saving model to output/dna_focal.keras
#
# Epoch 5: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0432 - pr_auc: 0.5255 - precision_1: 0.4800 - recall_1: 0.6281 - roc_auc: 0.8275 - val_loss: 0.0405 - val_pr_auc: 0.5908 - val_precision_1: 0.4718 - val_recall_1: 0.7414 - val_roc_auc: 0.8621 - learning_rate: 0.0010
# Epoch 6/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0408 - pr_auc: 0.5647 - precision_1: 0.5038 - recall_1: 0.6561 - roc_auc: 0.8508
# Epoch 6: val_pr_auc improved from 0.59076 to 0.59969, saving model to output/dna_focal.keras
#
# Epoch 6: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0418 - pr_auc: 0.5438 - precision_1: 0.4849 - recall_1: 0.6509 - roc_auc: 0.8437 - val_loss: 0.0395 - val_pr_auc: 0.5997 - val_precision_1: 0.4406 - val_recall_1: 0.7586 - val_roc_auc: 0.8613 - learning_rate: 0.0010
# Epoch 7/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0421 - pr_auc: 0.5498 - precision_1: 0.4872 - recall_1: 0.6346 - roc_auc: 0.8355
# Epoch 7: val_pr_auc improved from 0.59969 to 0.60101, saving model to output/dna_focal.keras
#
# Epoch 7: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0420 - pr_auc: 0.5601 - precision_1: 0.4958 - recall_1: 0.6607 - roc_auc: 0.8418 - val_loss: 0.0385 - val_pr_auc: 0.6010 - val_precision_1: 0.5986 - val_recall_1: 0.6207 - val_roc_auc: 0.8662 - learning_rate: 0.0010
# Epoch 8/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0407 - pr_auc: 0.5334 - precision_1: 0.4814 - recall_1: 0.6334 - roc_auc: 0.8403
# Epoch 8: val_pr_auc did not improve from 0.60101
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0422 - pr_auc: 0.5517 - precision_1: 0.4853 - recall_1: 0.6502 - roc_auc: 0.8384 - val_loss: 0.0428 - val_pr_auc: 0.5981 - val_precision_1: 0.6147 - val_recall_1: 0.5345 - val_roc_auc: 0.8662 - learning_rate: 0.0010
# Epoch 9/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0415 - pr_auc: 0.5721 - precision_1: 0.4969 - recall_1: 0.6655 - roc_auc: 0.8450
# Epoch 9: val_pr_auc did not improve from 0.60101
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0417 - pr_auc: 0.5604 - precision_1: 0.4872 - recall_1: 0.6564 - roc_auc: 0.8435 - val_loss: 0.0407 - val_pr_auc: 0.6010 - val_precision_1: 0.3864 - val_recall_1: 0.8251 - val_roc_auc: 0.8686 - learning_rate: 0.0010
# Epoch 10/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0419 - pr_auc: 0.5591 - precision_1: 0.4741 - recall_1: 0.6894 - roc_auc: 0.8456
# Epoch 10: val_pr_auc improved from 0.60101 to 0.60491, saving model to output/dna_focal.keras
#
# Epoch 10: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - loss: 0.0411 - pr_auc: 0.5633 - precision_1: 0.4797 - recall_1: 0.6755 - roc_auc: 0.8484 - val_loss: 0.0396 - val_pr_auc: 0.6049 - val_precision_1: 0.4274 - val_recall_1: 0.7980 - val_roc_auc: 0.8700 - learning_rate: 0.0010
# Epoch 11/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0448 - pr_auc: 0.5180 - precision_1: 0.4356 - recall_1: 0.6486 - roc_auc: 0.8202
# Epoch 11: val_pr_auc did not improve from 0.60491
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - loss: 0.0421 - pr_auc: 0.5512 - precision_1: 0.4680 - recall_1: 0.6539 - roc_auc: 0.8387 - val_loss: 0.0384 - val_pr_auc: 0.6045 - val_precision_1: 0.4676 - val_recall_1: 0.7463 - val_roc_auc: 0.8671 - learning_rate: 0.0010
# Epoch 12/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0430 - pr_auc: 0.5735 - precision_1: 0.4860 - recall_1: 0.6807 - roc_auc: 0.8464
# Epoch 12: val_pr_auc improved from 0.60491 to 0.60492, saving model to output/dna_focal.keras
#
# Epoch 12: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0417 - pr_auc: 0.5529 - precision_1: 0.4686 - recall_1: 0.6663 - roc_auc: 0.8438 - val_loss: 0.0376 - val_pr_auc: 0.6049 - val_precision_1: 0.4992 - val_recall_1: 0.7241 - val_roc_auc: 0.8693 - learning_rate: 0.0010
# Epoch 13/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0417 - pr_auc: 0.5790 - precision_1: 0.4802 - recall_1: 0.6736 - roc_auc: 0.8479
# Epoch 13: val_pr_auc improved from 0.60492 to 0.60802, saving model to output/dna_focal.keras
#
# Epoch 13: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0411 - pr_auc: 0.5750 - precision_1: 0.4785 - recall_1: 0.6767 - roc_auc: 0.8490 - val_loss: 0.0387 - val_pr_auc: 0.6080 - val_precision_1: 0.4720 - val_recall_1: 0.7463 - val_roc_auc: 0.8717 - learning_rate: 0.0010
# Epoch 14/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0414 - pr_auc: 0.6003 - precision_1: 0.4835 - recall_1: 0.7030 - roc_auc: 0.8567
# Epoch 14: val_pr_auc did not improve from 0.60802
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0405 - pr_auc: 0.5827 - precision_1: 0.4788 - recall_1: 0.6823 - roc_auc: 0.8535 - val_loss: 0.0377 - val_pr_auc: 0.6077 - val_precision_1: 0.4848 - val_recall_1: 0.7463 - val_roc_auc: 0.8706 - learning_rate: 0.0010
# Epoch 15/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0422 - pr_auc: 0.5909 - precision_1: 0.4782 - recall_1: 0.6914 - roc_auc: 0.8486
# Epoch 15: val_pr_auc improved from 0.60802 to 0.61218, saving model to output/dna_focal.keras
#
# Epoch 15: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0408 - pr_auc: 0.5856 - precision_1: 0.4759 - recall_1: 0.6933 - roc_auc: 0.8526 - val_loss: 0.0374 - val_pr_auc: 0.6122 - val_precision_1: 0.5089 - val_recall_1: 0.7044 - val_roc_auc: 0.8718 - learning_rate: 0.0010
# Epoch 16/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0408 - pr_auc: 0.5672 - precision_1: 0.5048 - recall_1: 0.6736 - roc_auc: 0.8483
# Epoch 16: val_pr_auc improved from 0.61218 to 0.61289, saving model to output/dna_focal.keras
#
# Epoch 16: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0409 - pr_auc: 0.5755 - precision_1: 0.4778 - recall_1: 0.6835 - roc_auc: 0.8506 - val_loss: 0.0383 - val_pr_auc: 0.6129 - val_precision_1: 0.4479 - val_recall_1: 0.7833 - val_roc_auc: 0.8720 - learning_rate: 0.0010
# Epoch 17/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0401 - pr_auc: 0.5950 - precision_1: 0.4735 - recall_1: 0.6683 - roc_auc: 0.8529
# Epoch 17: val_pr_auc did not improve from 0.61289
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0412 - pr_auc: 0.5801 - precision_1: 0.4790 - recall_1: 0.6730 - roc_auc: 0.8484 - val_loss: 0.0377 - val_pr_auc: 0.6114 - val_precision_1: 0.5184 - val_recall_1: 0.6946 - val_roc_auc: 0.8695 - learning_rate: 0.0010
# Epoch 18/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0403 - pr_auc: 0.5870 - precision_1: 0.4664 - recall_1: 0.6929 - roc_auc: 0.8540
# Epoch 18: val_pr_auc did not improve from 0.61289
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0414 - pr_auc: 0.5779 - precision_1: 0.4783 - recall_1: 0.6792 - roc_auc: 0.8467 - val_loss: 0.0403 - val_pr_auc: 0.6114 - val_precision_1: 0.3945 - val_recall_1: 0.8202 - val_roc_auc: 0.8708 - learning_rate: 0.0010
# Epoch 19/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0410 - pr_auc: 0.5695 - precision_1: 0.4766 - recall_1: 0.6908 - roc_auc: 0.8505
# Epoch 19: val_pr_auc did not improve from 0.61289
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0411 - pr_auc: 0.5686 - precision_1: 0.4717 - recall_1: 0.6915 - roc_auc: 0.8500 - val_loss: 0.0385 - val_pr_auc: 0.6125 - val_precision_1: 0.4523 - val_recall_1: 0.7709 - val_roc_auc: 0.8722 - learning_rate: 0.0010
# Epoch 20/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0393 - pr_auc: 0.5960 - precision_1: 0.4659 - recall_1: 0.6747 - roc_auc: 0.8573
# Epoch 20: val_pr_auc improved from 0.61289 to 0.61450, saving model to output/dna_focal.keras
#
# Epoch 20: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0408 - pr_auc: 0.5855 - precision_1: 0.4740 - recall_1: 0.6780 - roc_auc: 0.8520 - val_loss: 0.0384 - val_pr_auc: 0.6145 - val_precision_1: 0.4950 - val_recall_1: 0.7365 - val_roc_auc: 0.8720 - learning_rate: 0.0010
# Epoch 21/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0416 - pr_auc: 0.5766 - precision_1: 0.4793 - recall_1: 0.7019 - roc_auc: 0.8525
# Epoch 21: val_pr_auc improved from 0.61450 to 0.61518, saving model to output/dna_focal.keras
#
# Epoch 21: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0411 - pr_auc: 0.5617 - precision_1: 0.4820 - recall_1: 0.6847 - roc_auc: 0.8503 - val_loss: 0.0376 - val_pr_auc: 0.6152 - val_precision_1: 0.4787 - val_recall_1: 0.7463 - val_roc_auc: 0.8728 - learning_rate: 0.0010
# Epoch 22/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0410 - pr_auc: 0.5773 - precision_1: 0.4777 - recall_1: 0.6805 - roc_auc: 0.8492
# Epoch 22: val_pr_auc improved from 0.61518 to 0.61640, saving model to output/dna_focal.keras
#
# Epoch 22: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0408 - pr_auc: 0.5761 - precision_1: 0.4787 - recall_1: 0.6835 - roc_auc: 0.8512 - val_loss: 0.0377 - val_pr_auc: 0.6164 - val_precision_1: 0.6023 - val_recall_1: 0.6453 - val_roc_auc: 0.8732 - learning_rate: 0.0010
# Epoch 23/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0402 - pr_auc: 0.5799 - precision_1: 0.4914 - recall_1: 0.6731 - roc_auc: 0.8541
# Epoch 23: val_pr_auc did not improve from 0.61640
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0408 - pr_auc: 0.5799 - precision_1: 0.4878 - recall_1: 0.6669 - roc_auc: 0.8525 - val_loss: 0.0376 - val_pr_auc: 0.6163 - val_precision_1: 0.4847 - val_recall_1: 0.7414 - val_roc_auc: 0.8719 - learning_rate: 0.0010
# Epoch 24/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0404 - pr_auc: 0.5859 - precision_1: 0.4917 - recall_1: 0.6780 - roc_auc: 0.8555
# Epoch 24: val_pr_auc improved from 0.61640 to 0.61750, saving model to output/dna_focal.keras
#
# Epoch 24: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0409 - pr_auc: 0.5788 - precision_1: 0.4847 - recall_1: 0.6810 - roc_auc: 0.8522 - val_loss: 0.0372 - val_pr_auc: 0.6175 - val_precision_1: 0.5225 - val_recall_1: 0.7143 - val_roc_auc: 0.8730 - learning_rate: 0.0010
# Epoch 25/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0398 - pr_auc: 0.6100 - precision_1: 0.5016 - recall_1: 0.7083 - roc_auc: 0.8607
# Epoch 25: val_pr_auc improved from 0.61750 to 0.61792, saving model to output/dna_focal.keras
#
# Epoch 25: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0400 - pr_auc: 0.5973 - precision_1: 0.4888 - recall_1: 0.6989 - roc_auc: 0.8571 - val_loss: 0.0389 - val_pr_auc: 0.6179 - val_precision_1: 0.4714 - val_recall_1: 0.7512 - val_roc_auc: 0.8723 - learning_rate: 0.0010
# Epoch 26/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0401 - pr_auc: 0.6053 - precision_1: 0.4982 - recall_1: 0.6706 - roc_auc: 0.8573
# Epoch 26: val_pr_auc improved from 0.61792 to 0.61932, saving model to output/dna_focal.keras
#
# Epoch 26: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0402 - pr_auc: 0.5922 - precision_1: 0.4897 - recall_1: 0.6755 - roc_auc: 0.8558 - val_loss: 0.0387 - val_pr_auc: 0.6193 - val_precision_1: 0.6467 - val_recall_1: 0.5862 - val_roc_auc: 0.8746 - learning_rate: 0.0010
# Epoch 27/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0394 - pr_auc: 0.5683 - precision_1: 0.4785 - recall_1: 0.6838 - roc_auc: 0.8543
# Epoch 27: val_pr_auc did not improve from 0.61932
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0402 - pr_auc: 0.5865 - precision_1: 0.4908 - recall_1: 0.6921 - roc_auc: 0.8570 - val_loss: 0.0373 - val_pr_auc: 0.6191 - val_precision_1: 0.5131 - val_recall_1: 0.7241 - val_roc_auc: 0.8737 - learning_rate: 0.0010
# Epoch 28/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0404 - pr_auc: 0.5594 - precision_1: 0.4697 - recall_1: 0.6529 - roc_auc: 0.8467
# Epoch 28: val_pr_auc did not improve from 0.61932
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0400 - pr_auc: 0.5916 - precision_1: 0.4873 - recall_1: 0.6835 - roc_auc: 0.8564 - val_loss: 0.0380 - val_pr_auc: 0.6176 - val_precision_1: 0.5855 - val_recall_1: 0.6576 - val_roc_auc: 0.8704 - learning_rate: 0.0010
# Epoch 29/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0393 - pr_auc: 0.5888 - precision_1: 0.4828 - recall_1: 0.7010 - roc_auc: 0.8614
# Epoch 29: val_pr_auc did not improve from 0.61932
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0406 - pr_auc: 0.5806 - precision_1: 0.4702 - recall_1: 0.6958 - roc_auc: 0.8534 - val_loss: 0.0378 - val_pr_auc: 0.6002 - val_precision_1: 0.4680 - val_recall_1: 0.7562 - val_roc_auc: 0.8725 - learning_rate: 0.0010
# Epoch 30/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0407 - pr_auc: 0.5721 - precision_1: 0.4880 - recall_1: 0.6952 - roc_auc: 0.8549
# Epoch 30: val_pr_auc did not improve from 0.61932
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0406 - pr_auc: 0.5742 - precision_1: 0.4855 - recall_1: 0.6921 - roc_auc: 0.8539 - val_loss: 0.0373 - val_pr_auc: 0.6188 - val_precision_1: 0.5673 - val_recall_1: 0.6847 - val_roc_auc: 0.8714 - learning_rate: 0.0010
# Epoch 31/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.5938 - precision_1: 0.4891 - recall_1: 0.6706 - roc_auc: 0.8554
# Epoch 31: val_pr_auc improved from 0.61932 to 0.62008, saving model to output/dna_focal.keras
#
# Epoch 31: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0404 - pr_auc: 0.5898 - precision_1: 0.4906 - recall_1: 0.6730 - roc_auc: 0.8558 - val_loss: 0.0377 - val_pr_auc: 0.6201 - val_precision_1: 0.4975 - val_recall_1: 0.7315 - val_roc_auc: 0.8737 - learning_rate: 0.0010
# Epoch 32/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0410 - pr_auc: 0.5826 - precision_1: 0.4718 - recall_1: 0.6898 - roc_auc: 0.8532
# Epoch 32: val_pr_auc improved from 0.62008 to 0.62090, saving model to output/dna_focal.keras
#
# Epoch 32: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0402 - pr_auc: 0.5919 - precision_1: 0.4781 - recall_1: 0.6921 - roc_auc: 0.8556 - val_loss: 0.0372 - val_pr_auc: 0.6209 - val_precision_1: 0.5106 - val_recall_1: 0.7143 - val_roc_auc: 0.8728 - learning_rate: 0.0010
# Epoch 33/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.5869 - precision_1: 0.4850 - recall_1: 0.6868 - roc_auc: 0.8595
# Epoch 33: val_pr_auc did not improve from 0.62090
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0401 - pr_auc: 0.5883 - precision_1: 0.4853 - recall_1: 0.6903 - roc_auc: 0.8564 - val_loss: 0.0376 - val_pr_auc: 0.6208 - val_precision_1: 0.6127 - val_recall_1: 0.6429 - val_roc_auc: 0.8733 - learning_rate: 0.0010
# Epoch 34/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0405 - pr_auc: 0.5986 - precision_1: 0.4985 - recall_1: 0.6929 - roc_auc: 0.8582
# Epoch 34: val_pr_auc improved from 0.62090 to 0.62104, saving model to output/dna_focal.keras
#
# Epoch 34: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0399 - pr_auc: 0.6009 - precision_1: 0.4941 - recall_1: 0.6903 - roc_auc: 0.8580 - val_loss: 0.0371 - val_pr_auc: 0.6210 - val_precision_1: 0.5212 - val_recall_1: 0.6970 - val_roc_auc: 0.8736 - learning_rate: 0.0010
# Epoch 35/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0407 - pr_auc: 0.5912 - precision_1: 0.4769 - recall_1: 0.6907 - roc_auc: 0.8522
# Epoch 35: val_pr_auc improved from 0.62104 to 0.62462, saving model to output/dna_focal.keras
#
# Epoch 35: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0395 - pr_auc: 0.6026 - precision_1: 0.4823 - recall_1: 0.6952 - roc_auc: 0.8607 - val_loss: 0.0373 - val_pr_auc: 0.6246 - val_precision_1: 0.4983 - val_recall_1: 0.7315 - val_roc_auc: 0.8744 - learning_rate: 0.0010
# Epoch 36/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0390 - pr_auc: 0.6231 - precision_1: 0.4916 - recall_1: 0.7272 - roc_auc: 0.8712
# Epoch 36: val_pr_auc did not improve from 0.62462
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0398 - pr_auc: 0.5999 - precision_1: 0.4856 - recall_1: 0.7044 - roc_auc: 0.8606 - val_loss: 0.0389 - val_pr_auc: 0.6212 - val_precision_1: 0.6604 - val_recall_1: 0.6084 - val_roc_auc: 0.8742 - learning_rate: 0.0010
# Epoch 37/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0408 - pr_auc: 0.5852 - precision_1: 0.4879 - recall_1: 0.6511 - roc_auc: 0.8513
# Epoch 37: val_pr_auc did not improve from 0.62462
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0401 - pr_auc: 0.6000 - precision_1: 0.4944 - recall_1: 0.6847 - roc_auc: 0.8566 - val_loss: 0.0380 - val_pr_auc: 0.6217 - val_precision_1: 0.4597 - val_recall_1: 0.7586 - val_roc_auc: 0.8733 - learning_rate: 0.0010
# Epoch 38/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0394 - pr_auc: 0.5823 - precision_1: 0.4868 - recall_1: 0.7105 - roc_auc: 0.8594
# Epoch 38: val_pr_auc did not improve from 0.62462
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.6052 - precision_1: 0.4905 - recall_1: 0.7014 - roc_auc: 0.8620 - val_loss: 0.0374 - val_pr_auc: 0.6220 - val_precision_1: 0.4818 - val_recall_1: 0.7488 - val_roc_auc: 0.8737 - learning_rate: 0.0010
# Epoch 39/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0388 - pr_auc: 0.5972 - precision_1: 0.4851 - recall_1: 0.6977 - roc_auc: 0.8640
# Epoch 39: val_pr_auc improved from 0.62462 to 0.62655, saving model to output/dna_focal.keras
#
# Epoch 39: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0398 - pr_auc: 0.5970 - precision_1: 0.4835 - recall_1: 0.7038 - roc_auc: 0.8608 - val_loss: 0.0370 - val_pr_auc: 0.6266 - val_precision_1: 0.4810 - val_recall_1: 0.7463 - val_roc_auc: 0.8756 - learning_rate: 0.0010
# Epoch 40/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0387 - pr_auc: 0.6088 - precision_1: 0.4700 - recall_1: 0.6992 - roc_auc: 0.8647
# Epoch 40: val_pr_auc did not improve from 0.62655
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0403 - pr_auc: 0.5882 - precision_1: 0.4765 - recall_1: 0.6927 - roc_auc: 0.8569 - val_loss: 0.0372 - val_pr_auc: 0.6234 - val_precision_1: 0.5542 - val_recall_1: 0.6921 - val_roc_auc: 0.8742 - learning_rate: 0.0010
# Epoch 41/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6291 - precision_1: 0.5131 - recall_1: 0.6969 - roc_auc: 0.8659
# Epoch 41: val_pr_auc did not improve from 0.62655
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0392 - pr_auc: 0.6155 - precision_1: 0.4939 - recall_1: 0.7001 - roc_auc: 0.8627 - val_loss: 0.0374 - val_pr_auc: 0.6219 - val_precision_1: 0.4832 - val_recall_1: 0.7438 - val_roc_auc: 0.8743 - learning_rate: 0.0010
# Epoch 42/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0399 - pr_auc: 0.5849 - precision_1: 0.4891 - recall_1: 0.7057 - roc_auc: 0.8598
# Epoch 42: val_pr_auc did not improve from 0.62655
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0394 - pr_auc: 0.6001 - precision_1: 0.4924 - recall_1: 0.6977 - roc_auc: 0.8613 - val_loss: 0.0371 - val_pr_auc: 0.6251 - val_precision_1: 0.5122 - val_recall_1: 0.7241 - val_roc_auc: 0.8753 - learning_rate: 0.0010
# Epoch 43/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0403 - pr_auc: 0.6036 - precision_1: 0.4816 - recall_1: 0.7160 - roc_auc: 0.8611
# Epoch 43: val_pr_auc did not improve from 0.62655
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0394 - pr_auc: 0.6013 - precision_1: 0.4824 - recall_1: 0.6995 - roc_auc: 0.8621 - val_loss: 0.0381 - val_pr_auc: 0.6243 - val_precision_1: 0.6396 - val_recall_1: 0.6207 - val_roc_auc: 0.8734 - learning_rate: 0.0010
# Epoch 44/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.6054 - precision_1: 0.4911 - recall_1: 0.6910 - roc_auc: 0.8613
# Epoch 44: val_pr_auc did not improve from 0.62655
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0396 - pr_auc: 0.6021 - precision_1: 0.4772 - recall_1: 0.7020 - roc_auc: 0.8613 - val_loss: 0.0388 - val_pr_auc: 0.6253 - val_precision_1: 0.6488 - val_recall_1: 0.5961 - val_roc_auc: 0.8763 - learning_rate: 0.0010
# Epoch 45/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0393 - pr_auc: 0.6118 - precision_1: 0.5028 - recall_1: 0.6914 - roc_auc: 0.8651
# Epoch 45: val_pr_auc did not improve from 0.62655
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.6079 - precision_1: 0.4851 - recall_1: 0.6921 - roc_auc: 0.8624 - val_loss: 0.0373 - val_pr_auc: 0.6235 - val_precision_1: 0.4886 - val_recall_1: 0.7365 - val_roc_auc: 0.8725 - learning_rate: 0.0010
# Epoch 46/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - pr_auc: 0.5990 - precision_1: 0.4932 - recall_1: 0.7016 - roc_auc: 0.8601
# Epoch 46: val_pr_auc improved from 0.62655 to 0.62951, saving model to output/dna_focal.keras
#
# Epoch 46: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0396 - pr_auc: 0.6048 - precision_1: 0.4895 - recall_1: 0.7001 - roc_auc: 0.8617 - val_loss: 0.0386 - val_pr_auc: 0.6295 - val_precision_1: 0.4130 - val_recall_1: 0.8005 - val_roc_auc: 0.8766 - learning_rate: 0.0010
# Epoch 47/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0369 - pr_auc: 0.6125 - precision_1: 0.4928 - recall_1: 0.7146 - roc_auc: 0.8716
# Epoch 47: val_pr_auc did not improve from 0.62951
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0395 - pr_auc: 0.6061 - precision_1: 0.4878 - recall_1: 0.7044 - roc_auc: 0.8620 - val_loss: 0.0371 - val_pr_auc: 0.6291 - val_precision_1: 0.5226 - val_recall_1: 0.7118 - val_roc_auc: 0.8769 - learning_rate: 0.0010
# Epoch 48/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0390 - pr_auc: 0.5882 - precision_1: 0.4700 - recall_1: 0.6835 - roc_auc: 0.8551
# Epoch 48: val_pr_auc did not improve from 0.62951
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.6127 - precision_1: 0.4851 - recall_1: 0.7020 - roc_auc: 0.8624 - val_loss: 0.0386 - val_pr_auc: 0.6279 - val_precision_1: 0.4366 - val_recall_1: 0.7882 - val_roc_auc: 0.8761 - learning_rate: 0.0010
# Epoch 49/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0389 - pr_auc: 0.6217 - precision_1: 0.5019 - recall_1: 0.7400 - roc_auc: 0.8710
# Epoch 49: val_pr_auc improved from 0.62951 to 0.63015, saving model to output/dna_focal.keras
#
# Epoch 49: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.6188 - precision_1: 0.5044 - recall_1: 0.7100 - roc_auc: 0.8643 - val_loss: 0.0369 - val_pr_auc: 0.6302 - val_precision_1: 0.5861 - val_recall_1: 0.6872 - val_roc_auc: 0.8766 - learning_rate: 0.0010
# Epoch 50/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0390 - pr_auc: 0.6103 - precision_1: 0.5022 - recall_1: 0.6997 - roc_auc: 0.8680
# Epoch 50: val_pr_auc improved from 0.63015 to 0.63081, saving model to output/dna_focal.keras
#
# Epoch 50: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0394 - pr_auc: 0.6059 - precision_1: 0.4971 - recall_1: 0.6933 - roc_auc: 0.8642 - val_loss: 0.0372 - val_pr_auc: 0.6308 - val_precision_1: 0.4686 - val_recall_1: 0.7537 - val_roc_auc: 0.8774 - learning_rate: 0.0010
# Epoch 51/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0405 - pr_auc: 0.5772 - precision_1: 0.4870 - recall_1: 0.7128 - roc_auc: 0.8541
# Epoch 51: val_pr_auc improved from 0.63081 to 0.63089, saving model to output/dna_focal.keras
#
# Epoch 51: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.6006 - precision_1: 0.4893 - recall_1: 0.7198 - roc_auc: 0.8617 - val_loss: 0.0374 - val_pr_auc: 0.6309 - val_precision_1: 0.5281 - val_recall_1: 0.7167 - val_roc_auc: 0.8772 - learning_rate: 0.0010
# Epoch 52/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0387 - pr_auc: 0.6202 - precision_1: 0.5110 - recall_1: 0.7074 - roc_auc: 0.8675
# Epoch 52: val_pr_auc did not improve from 0.63089
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0391 - pr_auc: 0.6088 - precision_1: 0.4892 - recall_1: 0.6983 - roc_auc: 0.8640 - val_loss: 0.0378 - val_pr_auc: 0.6289 - val_precision_1: 0.6509 - val_recall_1: 0.6108 - val_roc_auc: 0.8763 - learning_rate: 0.0010
# Epoch 53/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0402 - pr_auc: 0.5894 - precision_1: 0.4865 - recall_1: 0.6855 - roc_auc: 0.8575
# Epoch 53: val_pr_auc did not improve from 0.63089
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0395 - pr_auc: 0.6005 - precision_1: 0.4928 - recall_1: 0.6952 - roc_auc: 0.8616 - val_loss: 0.0391 - val_pr_auc: 0.6279 - val_precision_1: 0.4046 - val_recall_1: 0.8251 - val_roc_auc: 0.8768 - learning_rate: 0.0010
# Epoch 54/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0397 - pr_auc: 0.5907 - precision_1: 0.4759 - recall_1: 0.7192 - roc_auc: 0.8624
# Epoch 54: val_pr_auc improved from 0.63089 to 0.63139, saving model to output/dna_focal.keras
#
# Epoch 54: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0397 - pr_auc: 0.6026 - precision_1: 0.5002 - recall_1: 0.7014 - roc_auc: 0.8617 - val_loss: 0.0366 - val_pr_auc: 0.6314 - val_precision_1: 0.5513 - val_recall_1: 0.7020 - val_roc_auc: 0.8783 - learning_rate: 0.0010
# Epoch 55/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0404 - pr_auc: 0.5447 - precision_1: 0.4522 - recall_1: 0.6715 - roc_auc: 0.8441
# Epoch 55: val_pr_auc improved from 0.63139 to 0.63252, saving model to output/dna_focal.keras
#
# Epoch 55: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0405 - pr_auc: 0.5769 - precision_1: 0.4775 - recall_1: 0.6927 - roc_auc: 0.8556 - val_loss: 0.0425 - val_pr_auc: 0.6325 - val_precision_1: 0.3372 - val_recall_1: 0.8670 - val_roc_auc: 0.8750 - learning_rate: 0.0010
# Epoch 56/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0386 - pr_auc: 0.6005 - precision_1: 0.4885 - recall_1: 0.7268 - roc_auc: 0.8660
# Epoch 56: val_pr_auc improved from 0.63252 to 0.63293, saving model to output/dna_focal.keras
#
# Epoch 56: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0391 - pr_auc: 0.6122 - precision_1: 0.4934 - recall_1: 0.7094 - roc_auc: 0.8641 - val_loss: 0.0385 - val_pr_auc: 0.6329 - val_precision_1: 0.6519 - val_recall_1: 0.6182 - val_roc_auc: 0.8780 - learning_rate: 0.0010
# Epoch 57/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0412 - pr_auc: 0.6009 - precision_1: 0.4983 - recall_1: 0.6743 - roc_auc: 0.8584
# Epoch 57: val_pr_auc did not improve from 0.63293
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0398 - pr_auc: 0.6025 - precision_1: 0.4991 - recall_1: 0.6897 - roc_auc: 0.8618 - val_loss: 0.0384 - val_pr_auc: 0.6279 - val_precision_1: 0.6528 - val_recall_1: 0.5788 - val_roc_auc: 0.8738 - learning_rate: 0.0010
# Epoch 58/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0390 - pr_auc: 0.5932 - precision_1: 0.5016 - recall_1: 0.6828 - roc_auc: 0.8594
# Epoch 58: val_pr_auc did not improve from 0.63293
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0390 - pr_auc: 0.6126 - precision_1: 0.4983 - recall_1: 0.7075 - roc_auc: 0.8643 - val_loss: 0.0367 - val_pr_auc: 0.6306 - val_precision_1: 0.5446 - val_recall_1: 0.6921 - val_roc_auc: 0.8767 - learning_rate: 0.0010
# Epoch 59/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0386 - pr_auc: 0.6293 - precision_1: 0.5023 - recall_1: 0.7171 - roc_auc: 0.8696
# Epoch 59: val_pr_auc improved from 0.63293 to 0.63535, saving model to output/dna_focal.keras
#
# Epoch 59: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0392 - pr_auc: 0.6070 - precision_1: 0.5002 - recall_1: 0.7014 - roc_auc: 0.8638 - val_loss: 0.0388 - val_pr_auc: 0.6353 - val_precision_1: 0.4173 - val_recall_1: 0.8079 - val_roc_auc: 0.8774 - learning_rate: 0.0010
# Epoch 60/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0393 - pr_auc: 0.6117 - precision_1: 0.4933 - recall_1: 0.7114 - roc_auc: 0.8667
# Epoch 60: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0390 - pr_auc: 0.6022 - precision_1: 0.4944 - recall_1: 0.7081 - roc_auc: 0.8650 - val_loss: 0.0385 - val_pr_auc: 0.6343 - val_precision_1: 0.4068 - val_recall_1: 0.8227 - val_roc_auc: 0.8775 - learning_rate: 0.0010
# Epoch 61/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0377 - pr_auc: 0.6045 - precision_1: 0.4730 - recall_1: 0.7098 - roc_auc: 0.8679
# Epoch 61: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0392 - pr_auc: 0.6069 - precision_1: 0.4887 - recall_1: 0.6952 - roc_auc: 0.8638 - val_loss: 0.0373 - val_pr_auc: 0.6299 - val_precision_1: 0.5060 - val_recall_1: 0.7241 - val_roc_auc: 0.8775 - learning_rate: 0.0010
# Epoch 62/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0383 - pr_auc: 0.6059 - precision_1: 0.5030 - recall_1: 0.7129 - roc_auc: 0.8668
# Epoch 62: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0387 - pr_auc: 0.6145 - precision_1: 0.5087 - recall_1: 0.7038 - roc_auc: 0.8658 - val_loss: 0.0369 - val_pr_auc: 0.6315 - val_precision_1: 0.4766 - val_recall_1: 0.7512 - val_roc_auc: 0.8777 - learning_rate: 0.0010
# Epoch 63/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0407 - pr_auc: 0.6127 - precision_1: 0.4836 - recall_1: 0.6999 - roc_auc: 0.8640
# Epoch 63: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0395 - pr_auc: 0.6065 - precision_1: 0.4861 - recall_1: 0.6897 - roc_auc: 0.8623 - val_loss: 0.0368 - val_pr_auc: 0.6311 - val_precision_1: 0.5237 - val_recall_1: 0.7069 - val_roc_auc: 0.8762 - learning_rate: 0.0010
# Epoch 64/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0380 - pr_auc: 0.6220 - precision_1: 0.5011 - recall_1: 0.7306 - roc_auc: 0.8781
# Epoch 64: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0391 - pr_auc: 0.6019 - precision_1: 0.4897 - recall_1: 0.7050 - roc_auc: 0.8651 - val_loss: 0.0416 - val_pr_auc: 0.6302 - val_precision_1: 0.4841 - val_recall_1: 0.7488 - val_roc_auc: 0.8790 - learning_rate: 0.0010
# Epoch 65/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0399 - pr_auc: 0.6046 - precision_1: 0.5076 - recall_1: 0.7022 - roc_auc: 0.8623
# Epoch 65: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0390 - pr_auc: 0.6111 - precision_1: 0.5007 - recall_1: 0.7069 - roc_auc: 0.8651 - val_loss: 0.0367 - val_pr_auc: 0.6297 - val_precision_1: 0.5560 - val_recall_1: 0.6970 - val_roc_auc: 0.8766 - learning_rate: 0.0010
# Epoch 66/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0388 - pr_auc: 0.6166 - precision_1: 0.5050 - recall_1: 0.7307 - roc_auc: 0.8690
# Epoch 66: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0387 - pr_auc: 0.6134 - precision_1: 0.4938 - recall_1: 0.7155 - roc_auc: 0.8668 - val_loss: 0.0370 - val_pr_auc: 0.6333 - val_precision_1: 0.4663 - val_recall_1: 0.7660 - val_roc_auc: 0.8779 - learning_rate: 0.0010
# Epoch 67/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6066 - precision_1: 0.4760 - recall_1: 0.7299 - roc_auc: 0.8665
# Epoch 67: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0392 - pr_auc: 0.6043 - precision_1: 0.4833 - recall_1: 0.7131 - roc_auc: 0.8634 - val_loss: 0.0374 - val_pr_auc: 0.6329 - val_precision_1: 0.4730 - val_recall_1: 0.7537 - val_roc_auc: 0.8787 - learning_rate: 0.0010
# Epoch 68/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0385 - pr_auc: 0.6176 - precision_1: 0.4981 - recall_1: 0.7214 - roc_auc: 0.8689
# Epoch 68: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.6075 - precision_1: 0.4943 - recall_1: 0.6995 - roc_auc: 0.8639 - val_loss: 0.0386 - val_pr_auc: 0.6326 - val_precision_1: 0.4465 - val_recall_1: 0.7808 - val_roc_auc: 0.8786 - learning_rate: 0.0010
# Epoch 69/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0393 - pr_auc: 0.6221 - precision_1: 0.5041 - recall_1: 0.7045 - roc_auc: 0.8687
# Epoch 69: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.5969 - precision_1: 0.4950 - recall_1: 0.6983 - roc_auc: 0.8633 - val_loss: 0.0376 - val_pr_auc: 0.6336 - val_precision_1: 0.5680 - val_recall_1: 0.6897 - val_roc_auc: 0.8772 - learning_rate: 0.0010
# Epoch 70/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - pr_auc: 0.6192 - precision_1: 0.5098 - recall_1: 0.7177 - roc_auc: 0.8646
# Epoch 70: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0385 - pr_auc: 0.6218 - precision_1: 0.5056 - recall_1: 0.7204 - roc_auc: 0.8706 - val_loss: 0.0369 - val_pr_auc: 0.6335 - val_precision_1: 0.5095 - val_recall_1: 0.7291 - val_roc_auc: 0.8778 - learning_rate: 5.0000e-04
# Epoch 71/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0383 - pr_auc: 0.6300 - precision_1: 0.4994 - recall_1: 0.7152 - roc_auc: 0.8708
# Epoch 71: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0385 - pr_auc: 0.6260 - precision_1: 0.5054 - recall_1: 0.7217 - roc_auc: 0.8703 - val_loss: 0.0371 - val_pr_auc: 0.6340 - val_precision_1: 0.4975 - val_recall_1: 0.7389 - val_roc_auc: 0.8789 - learning_rate: 5.0000e-04
# Epoch 72/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6346 - precision_1: 0.4945 - recall_1: 0.7358 - roc_auc: 0.8764
# Epoch 72: val_pr_auc did not improve from 0.63535
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6209 - precision_1: 0.4930 - recall_1: 0.7174 - roc_auc: 0.8712 - val_loss: 0.0371 - val_pr_auc: 0.6341 - val_precision_1: 0.4926 - val_recall_1: 0.7389 - val_roc_auc: 0.8779 - learning_rate: 5.0000e-04
# Epoch 73/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0385 - pr_auc: 0.6198 - precision_1: 0.4915 - recall_1: 0.7241 - roc_auc: 0.8706
# Epoch 73: val_pr_auc improved from 0.63535 to 0.63556, saving model to output/dna_focal.keras
#
# Epoch 73: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0380 - pr_auc: 0.6281 - precision_1: 0.5004 - recall_1: 0.7081 - roc_auc: 0.8719 - val_loss: 0.0369 - val_pr_auc: 0.6356 - val_precision_1: 0.5111 - val_recall_1: 0.7365 - val_roc_auc: 0.8789 - learning_rate: 5.0000e-04
# Epoch 74/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0367 - pr_auc: 0.6280 - precision_1: 0.5093 - recall_1: 0.7354 - roc_auc: 0.8801
# Epoch 74: val_pr_auc did not improve from 0.63556
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0384 - pr_auc: 0.6146 - precision_1: 0.4964 - recall_1: 0.7137 - roc_auc: 0.8701 - val_loss: 0.0383 - val_pr_auc: 0.6328 - val_precision_1: 0.4406 - val_recall_1: 0.7857 - val_roc_auc: 0.8779 - learning_rate: 5.0000e-04
# Epoch 75/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0386 - pr_auc: 0.6100 - precision_1: 0.5084 - recall_1: 0.7089 - roc_auc: 0.8682
# Epoch 75: val_pr_auc did not improve from 0.63556
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0384 - pr_auc: 0.6216 - precision_1: 0.4998 - recall_1: 0.7155 - roc_auc: 0.8691 - val_loss: 0.0369 - val_pr_auc: 0.6355 - val_precision_1: 0.5780 - val_recall_1: 0.6847 - val_roc_auc: 0.8783 - learning_rate: 5.0000e-04
# Epoch 76/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0387 - pr_auc: 0.6034 - precision_1: 0.4980 - recall_1: 0.7173 - roc_auc: 0.8650
# Epoch 76: val_pr_auc did not improve from 0.63556
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0383 - pr_auc: 0.6241 - precision_1: 0.4975 - recall_1: 0.7223 - roc_auc: 0.8712 - val_loss: 0.0382 - val_pr_auc: 0.6324 - val_precision_1: 0.4344 - val_recall_1: 0.7906 - val_roc_auc: 0.8774 - learning_rate: 5.0000e-04
# Epoch 77/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - pr_auc: 0.6168 - precision_1: 0.4955 - recall_1: 0.7159 - roc_auc: 0.8706
# Epoch 77: val_pr_auc did not improve from 0.63556
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6248 - precision_1: 0.4987 - recall_1: 0.7192 - roc_auc: 0.8719 - val_loss: 0.0371 - val_pr_auc: 0.6355 - val_precision_1: 0.5017 - val_recall_1: 0.7365 - val_roc_auc: 0.8781 - learning_rate: 5.0000e-04
# Epoch 78/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0381 - pr_auc: 0.6340 - precision_1: 0.4909 - recall_1: 0.7226 - roc_auc: 0.8724
# Epoch 78: val_pr_auc did not improve from 0.63556
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6272 - precision_1: 0.4947 - recall_1: 0.7149 - roc_auc: 0.8715 - val_loss: 0.0377 - val_pr_auc: 0.6335 - val_precision_1: 0.4658 - val_recall_1: 0.7537 - val_roc_auc: 0.8780 - learning_rate: 5.0000e-04
# Epoch 79/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0375 - pr_auc: 0.6319 - precision_1: 0.5103 - recall_1: 0.7308 - roc_auc: 0.8796
# Epoch 79: val_pr_auc did not improve from 0.63556
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0381 - pr_auc: 0.6167 - precision_1: 0.5015 - recall_1: 0.7149 - roc_auc: 0.8721 - val_loss: 0.0370 - val_pr_auc: 0.6351 - val_precision_1: 0.5076 - val_recall_1: 0.7365 - val_roc_auc: 0.8760 - learning_rate: 5.0000e-04
# Epoch 80/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0389 - pr_auc: 0.6493 - precision_1: 0.5052 - recall_1: 0.7538 - roc_auc: 0.8768
# Epoch 80: val_pr_auc improved from 0.63556 to 0.63692, saving model to output/dna_focal.keras
#
# Epoch 80: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6244 - precision_1: 0.4893 - recall_1: 0.7180 - roc_auc: 0.8702 - val_loss: 0.0377 - val_pr_auc: 0.6369 - val_precision_1: 0.5051 - val_recall_1: 0.7340 - val_roc_auc: 0.8780 - learning_rate: 5.0000e-04
# Epoch 81/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0390 - pr_auc: 0.5917 - precision_1: 0.4843 - recall_1: 0.7015 - roc_auc: 0.8648
# Epoch 81: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6274 - precision_1: 0.4983 - recall_1: 0.7278 - roc_auc: 0.8713 - val_loss: 0.0368 - val_pr_auc: 0.6348 - val_precision_1: 0.5242 - val_recall_1: 0.7192 - val_roc_auc: 0.8783 - learning_rate: 5.0000e-04
# Epoch 82/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0401 - pr_auc: 0.6171 - precision_1: 0.4936 - recall_1: 0.7069 - roc_auc: 0.8648
# Epoch 82: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6202 - precision_1: 0.4953 - recall_1: 0.7149 - roc_auc: 0.8720 - val_loss: 0.0372 - val_pr_auc: 0.6363 - val_precision_1: 0.5823 - val_recall_1: 0.6798 - val_roc_auc: 0.8784 - learning_rate: 5.0000e-04
# Epoch 83/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0390 - pr_auc: 0.6168 - precision_1: 0.4908 - recall_1: 0.6909 - roc_auc: 0.8662
# Epoch 83: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0384 - pr_auc: 0.6179 - precision_1: 0.4953 - recall_1: 0.7112 - roc_auc: 0.8710 - val_loss: 0.0369 - val_pr_auc: 0.6359 - val_precision_1: 0.5111 - val_recall_1: 0.7365 - val_roc_auc: 0.8789 - learning_rate: 5.0000e-04
# Epoch 84/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0361 - pr_auc: 0.6295 - precision_1: 0.5008 - recall_1: 0.7295 - roc_auc: 0.8812
# Epoch 84: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6251 - precision_1: 0.4985 - recall_1: 0.7118 - roc_auc: 0.8724 - val_loss: 0.0372 - val_pr_auc: 0.6330 - val_precision_1: 0.5429 - val_recall_1: 0.7020 - val_roc_auc: 0.8744 - learning_rate: 5.0000e-04
# Epoch 85/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0385 - pr_auc: 0.6179 - precision_1: 0.4935 - recall_1: 0.7234 - roc_auc: 0.8668
# Epoch 85: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0385 - pr_auc: 0.6198 - precision_1: 0.4949 - recall_1: 0.7223 - roc_auc: 0.8705 - val_loss: 0.0369 - val_pr_auc: 0.6365 - val_precision_1: 0.5515 - val_recall_1: 0.6995 - val_roc_auc: 0.8779 - learning_rate: 5.0000e-04
# Epoch 86/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0388 - pr_auc: 0.6167 - precision_1: 0.4999 - recall_1: 0.6928 - roc_auc: 0.8688
# Epoch 86: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0386 - pr_auc: 0.6213 - precision_1: 0.4915 - recall_1: 0.7149 - roc_auc: 0.8724 - val_loss: 0.0372 - val_pr_auc: 0.6357 - val_precision_1: 0.4765 - val_recall_1: 0.7488 - val_roc_auc: 0.8779 - learning_rate: 5.0000e-04
# Epoch 87/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0390 - pr_auc: 0.6232 - precision_1: 0.4998 - recall_1: 0.7150 - roc_auc: 0.8712
# Epoch 87: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6229 - precision_1: 0.4978 - recall_1: 0.7087 - roc_auc: 0.8741 - val_loss: 0.0371 - val_pr_auc: 0.6357 - val_precision_1: 0.4841 - val_recall_1: 0.7512 - val_roc_auc: 0.8778 - learning_rate: 5.0000e-04
# Epoch 88/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0375 - pr_auc: 0.6141 - precision_1: 0.4917 - recall_1: 0.7415 - roc_auc: 0.8735
# Epoch 88: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0386 - pr_auc: 0.6121 - precision_1: 0.4901 - recall_1: 0.7174 - roc_auc: 0.8701 - val_loss: 0.0373 - val_pr_auc: 0.6347 - val_precision_1: 0.4587 - val_recall_1: 0.7660 - val_roc_auc: 0.8784 - learning_rate: 5.0000e-04
# Epoch 89/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6395 - precision_1: 0.4907 - recall_1: 0.7311 - roc_auc: 0.8771
# Epoch 89: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6256 - precision_1: 0.4964 - recall_1: 0.7278 - roc_auc: 0.8719 - val_loss: 0.0366 - val_pr_auc: 0.6364 - val_precision_1: 0.5517 - val_recall_1: 0.6970 - val_roc_auc: 0.8786 - learning_rate: 5.0000e-04
# Epoch 90/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0374 - pr_auc: 0.6181 - precision_1: 0.4871 - recall_1: 0.7027 - roc_auc: 0.8732
# Epoch 90: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0381 - pr_auc: 0.6206 - precision_1: 0.4912 - recall_1: 0.7241 - roc_auc: 0.8732 - val_loss: 0.0368 - val_pr_auc: 0.6350 - val_precision_1: 0.5159 - val_recall_1: 0.7192 - val_roc_auc: 0.8764 - learning_rate: 5.0000e-04
# Epoch 91/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0366 - pr_auc: 0.6311 - precision_1: 0.5166 - recall_1: 0.7394 - roc_auc: 0.8812
# Epoch 91: val_pr_auc did not improve from 0.63692
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6227 - precision_1: 0.5004 - recall_1: 0.7352 - roc_auc: 0.8741 - val_loss: 0.0374 - val_pr_auc: 0.6366 - val_precision_1: 0.4741 - val_recall_1: 0.7438 - val_roc_auc: 0.8781 - learning_rate: 2.5000e-04
# Epoch 92/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0382 - pr_auc: 0.6254 - precision_1: 0.4884 - recall_1: 0.7606 - roc_auc: 0.8783
# Epoch 92: val_pr_auc improved from 0.63692 to 0.63719, saving model to output/dna_focal.keras
#
# Epoch 92: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6299 - precision_1: 0.4937 - recall_1: 0.7457 - roc_auc: 0.8742 - val_loss: 0.0371 - val_pr_auc: 0.6372 - val_precision_1: 0.5251 - val_recall_1: 0.7217 - val_roc_auc: 0.8776 - learning_rate: 2.5000e-04
# Epoch 93/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0366 - pr_auc: 0.6419 - precision_1: 0.5202 - recall_1: 0.7171 - roc_auc: 0.8772
# Epoch 93: val_pr_auc did not improve from 0.63719
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6281 - precision_1: 0.4992 - recall_1: 0.7315 - roc_auc: 0.8754 - val_loss: 0.0371 - val_pr_auc: 0.6370 - val_precision_1: 0.4721 - val_recall_1: 0.7512 - val_roc_auc: 0.8782 - learning_rate: 2.5000e-04
# Epoch 94/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.6221 - precision_1: 0.4892 - recall_1: 0.7403 - roc_auc: 0.8700
# Epoch 94: val_pr_auc improved from 0.63719 to 0.63824, saving model to output/dna_focal.keras
#
# Epoch 94: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6309 - precision_1: 0.4888 - recall_1: 0.7377 - roc_auc: 0.8747 - val_loss: 0.0370 - val_pr_auc: 0.6382 - val_precision_1: 0.5269 - val_recall_1: 0.7241 - val_roc_auc: 0.8775 - learning_rate: 2.5000e-04
# Epoch 95/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0371 - pr_auc: 0.6463 - precision_1: 0.5137 - recall_1: 0.7321 - roc_auc: 0.8789
# Epoch 95: val_pr_auc did not improve from 0.63824
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6282 - precision_1: 0.4944 - recall_1: 0.7340 - roc_auc: 0.8745 - val_loss: 0.0372 - val_pr_auc: 0.6366 - val_precision_1: 0.4665 - val_recall_1: 0.7537 - val_roc_auc: 0.8774 - learning_rate: 2.5000e-04
# Epoch 96/200
# ...
# Epoch 115: val_pr_auc did not improve from 0.64305
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6277 - precision_1: 0.5013 - recall_1: 0.7248 - roc_auc: 0.8760 - val_loss: 0.0374 - val_pr_auc: 0.6427 - val_precision_1: 0.4863 - val_recall_1: 0.7414 - val_roc_auc: 0.8788 - learning_rate: 2.5000e-04
# Epoch 116/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6401 - precision_1: 0.5124 - recall_1: 0.7369 - roc_auc: 0.8755
# Epoch 116: val_pr_auc improved from 0.64305 to 0.64374, saving model to output/dna_focal.keras
#
# Epoch 116: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0373 - pr_auc: 0.6350 - precision_1: 0.5067 - recall_1: 0.7229 - roc_auc: 0.8778 - val_loss: 0.0375 - val_pr_auc: 0.6437 - val_precision_1: 0.5076 - val_recall_1: 0.7365 - val_roc_auc: 0.8779 - learning_rate: 2.5000e-04
# Epoch 117/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6297 - precision_1: 0.5228 - recall_1: 0.7386 - roc_auc: 0.8778
# Epoch 117: val_pr_auc did not improve from 0.64374
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6284 - precision_1: 0.5072 - recall_1: 0.7334 - roc_auc: 0.8761 - val_loss: 0.0371 - val_pr_auc: 0.6430 - val_precision_1: 0.4910 - val_recall_1: 0.7389 - val_roc_auc: 0.8780 - learning_rate: 2.5000e-04
# Epoch 118/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0383 - pr_auc: 0.6589 - precision_1: 0.5057 - recall_1: 0.7479 - roc_auc: 0.8820
# Epoch 118: val_pr_auc improved from 0.64374 to 0.64379, saving model to output/dna_focal.keras
#
# Epoch 118: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0376 - pr_auc: 0.6407 - precision_1: 0.4964 - recall_1: 0.7297 - roc_auc: 0.8771 - val_loss: 0.0372 - val_pr_auc: 0.6438 - val_precision_1: 0.5086 - val_recall_1: 0.7315 - val_roc_auc: 0.8782 - learning_rate: 2.5000e-04
# Epoch 119/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0384 - pr_auc: 0.6350 - precision_1: 0.5010 - recall_1: 0.7392 - roc_auc: 0.8736
# Epoch 119: val_pr_auc improved from 0.64379 to 0.64490, saving model to output/dna_focal.keras
#
# Epoch 119: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0373 - pr_auc: 0.6352 - precision_1: 0.5032 - recall_1: 0.7291 - roc_auc: 0.8772 - val_loss: 0.0379 - val_pr_auc: 0.6449 - val_precision_1: 0.5076 - val_recall_1: 0.7389 - val_roc_auc: 0.8785 - learning_rate: 2.5000e-04
# Epoch 120/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0369 - pr_auc: 0.6446 - precision_1: 0.5089 - recall_1: 0.7489 - roc_auc: 0.8813
# Epoch 120: val_pr_auc did not improve from 0.64490
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6354 - precision_1: 0.5002 - recall_1: 0.7371 - roc_auc: 0.8774 - val_loss: 0.0366 - val_pr_auc: 0.6438 - val_precision_1: 0.5111 - val_recall_1: 0.7389 - val_roc_auc: 0.8789 - learning_rate: 2.5000e-04
# Epoch 121/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6275 - precision_1: 0.4964 - recall_1: 0.7280 - roc_auc: 0.8768
# Epoch 121: val_pr_auc improved from 0.64490 to 0.64780, saving model to output/dna_focal.keras
#
# Epoch 121: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0376 - pr_auc: 0.6333 - precision_1: 0.5006 - recall_1: 0.7346 - roc_auc: 0.8783 - val_loss: 0.0371 - val_pr_auc: 0.6478 - val_precision_1: 0.4708 - val_recall_1: 0.7537 - val_roc_auc: 0.8785 - learning_rate: 2.5000e-04
# Epoch 122/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0374 - pr_auc: 0.6306 - precision_1: 0.4901 - recall_1: 0.7446 - roc_auc: 0.8797
# Epoch 122: val_pr_auc did not improve from 0.64780
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0375 - pr_auc: 0.6351 - precision_1: 0.4996 - recall_1: 0.7340 - roc_auc: 0.8772 - val_loss: 0.0371 - val_pr_auc: 0.6449 - val_precision_1: 0.5042 - val_recall_1: 0.7389 - val_roc_auc: 0.8775 - learning_rate: 2.5000e-04
# Epoch 123/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0377 - pr_auc: 0.6377 - precision_1: 0.4973 - recall_1: 0.7313 - roc_auc: 0.8746
# Epoch 123: val_pr_auc did not improve from 0.64780
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0376 - pr_auc: 0.6316 - precision_1: 0.4952 - recall_1: 0.7284 - roc_auc: 0.8762 - val_loss: 0.0378 - val_pr_auc: 0.6434 - val_precision_1: 0.4406 - val_recall_1: 0.7759 - val_roc_auc: 0.8759 - learning_rate: 2.5000e-04
# Epoch 124/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6243 - precision_1: 0.4908 - recall_1: 0.7338 - roc_auc: 0.8765
# Epoch 124: val_pr_auc did not improve from 0.64780
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6328 - precision_1: 0.4977 - recall_1: 0.7352 - roc_auc: 0.8776 - val_loss: 0.0375 - val_pr_auc: 0.6442 - val_precision_1: 0.5425 - val_recall_1: 0.6921 - val_roc_auc: 0.8778 - learning_rate: 2.5000e-04
# Epoch 125/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0366 - pr_auc: 0.6307 - precision_1: 0.5058 - recall_1: 0.7151 - roc_auc: 0.8791
# Epoch 125: val_pr_auc did not improve from 0.64780
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0375 - pr_auc: 0.6344 - precision_1: 0.5011 - recall_1: 0.7266 - roc_auc: 0.8777 - val_loss: 0.0372 - val_pr_auc: 0.6450 - val_precision_1: 0.4959 - val_recall_1: 0.7365 - val_roc_auc: 0.8772 - learning_rate: 2.5000e-04
# Epoch 126/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0355 - pr_auc: 0.6700 - precision_1: 0.5346 - recall_1: 0.7430 - roc_auc: 0.8895
# Epoch 126: val_pr_auc did not improve from 0.64780
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0373 - pr_auc: 0.6356 - precision_1: 0.5069 - recall_1: 0.7241 - roc_auc: 0.8792 - val_loss: 0.0373 - val_pr_auc: 0.6457 - val_precision_1: 0.5353 - val_recall_1: 0.7094 - val_roc_auc: 0.8776 - learning_rate: 2.5000e-04
# Epoch 127/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0376 - pr_auc: 0.6569 - precision_1: 0.5121 - recall_1: 0.7624 - roc_auc: 0.8849
# Epoch 127: val_pr_auc improved from 0.64780 to 0.65208, saving model to output/dna_focal.keras
#
# Epoch 127: finished saving model to output/dna_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6317 - precision_1: 0.4906 - recall_1: 0.7426 - roc_auc: 0.8781 - val_loss: 0.0372 - val_pr_auc: 0.6521 - val_precision_1: 0.5025 - val_recall_1: 0.7438 - val_roc_auc: 0.8783 - learning_rate: 2.5000e-04
# Epoch 128/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0360 - pr_auc: 0.6218 - precision_1: 0.4880 - recall_1: 0.7223 - roc_auc: 0.8805
# Epoch 128: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6362 - precision_1: 0.4939 - recall_1: 0.7278 - roc_auc: 0.8778 - val_loss: 0.0376 - val_pr_auc: 0.6420 - val_precision_1: 0.5123 - val_recall_1: 0.7192 - val_roc_auc: 0.8756 - learning_rate: 2.5000e-04
# Epoch 129/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6415 - precision_1: 0.4964 - recall_1: 0.7296 - roc_auc: 0.8796
# Epoch 129: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6353 - precision_1: 0.4952 - recall_1: 0.7315 - roc_auc: 0.8776 - val_loss: 0.0375 - val_pr_auc: 0.6455 - val_precision_1: 0.5008 - val_recall_1: 0.7389 - val_roc_auc: 0.8778 - learning_rate: 2.5000e-04
# Epoch 130/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0371 - pr_auc: 0.6698 - precision_1: 0.5223 - recall_1: 0.7490 - roc_auc: 0.8878
# Epoch 130: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6334 - precision_1: 0.5023 - recall_1: 0.7284 - roc_auc: 0.8770 - val_loss: 0.0374 - val_pr_auc: 0.6465 - val_precision_1: 0.4619 - val_recall_1: 0.7611 - val_roc_auc: 0.8771 - learning_rate: 2.5000e-04
# Epoch 131/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0362 - pr_auc: 0.6593 - precision_1: 0.4987 - recall_1: 0.7586 - roc_auc: 0.8884
# Epoch 131: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6368 - precision_1: 0.4967 - recall_1: 0.7371 - roc_auc: 0.8780 - val_loss: 0.0375 - val_pr_auc: 0.6449 - val_precision_1: 0.5220 - val_recall_1: 0.7315 - val_roc_auc: 0.8782 - learning_rate: 2.5000e-04
# Epoch 132/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0379 - pr_auc: 0.6400 - precision_1: 0.5120 - recall_1: 0.7377 - roc_auc: 0.8796
# Epoch 132: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6345 - precision_1: 0.4979 - recall_1: 0.7328 - roc_auc: 0.8781 - val_loss: 0.0395 - val_pr_auc: 0.6434 - val_precision_1: 0.5720 - val_recall_1: 0.6749 - val_roc_auc: 0.8720 - learning_rate: 2.5000e-04
# Epoch 133/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0371 - pr_auc: 0.6432 - precision_1: 0.5198 - recall_1: 0.7372 - roc_auc: 0.8832
# Epoch 133: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6296 - precision_1: 0.5032 - recall_1: 0.7297 - roc_auc: 0.8785 - val_loss: 0.0378 - val_pr_auc: 0.6480 - val_precision_1: 0.5341 - val_recall_1: 0.7143 - val_roc_auc: 0.8785 - learning_rate: 2.5000e-04
# Epoch 134/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0361 - pr_auc: 0.6459 - precision_1: 0.5035 - recall_1: 0.7624 - roc_auc: 0.8877
# Epoch 134: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6404 - precision_1: 0.4996 - recall_1: 0.7420 - roc_auc: 0.8800 - val_loss: 0.0375 - val_pr_auc: 0.6404 - val_precision_1: 0.4677 - val_recall_1: 0.7488 - val_roc_auc: 0.8717 - learning_rate: 2.5000e-04
# Epoch 135/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0377 - pr_auc: 0.6239 - precision_1: 0.5037 - recall_1: 0.7566 - roc_auc: 0.8775
# Epoch 135: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6315 - precision_1: 0.5029 - recall_1: 0.7395 - roc_auc: 0.8759 - val_loss: 0.0379 - val_pr_auc: 0.6453 - val_precision_1: 0.4490 - val_recall_1: 0.7808 - val_roc_auc: 0.8780 - learning_rate: 2.5000e-04
# Epoch 136/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0359 - pr_auc: 0.6533 - precision_1: 0.5173 - recall_1: 0.7541 - roc_auc: 0.8853
# Epoch 136: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0371 - pr_auc: 0.6373 - precision_1: 0.5061 - recall_1: 0.7352 - roc_auc: 0.8789 - val_loss: 0.0382 - val_pr_auc: 0.6480 - val_precision_1: 0.4688 - val_recall_1: 0.7586 - val_roc_auc: 0.8770 - learning_rate: 2.5000e-04
# Epoch 137/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0374 - pr_auc: 0.6268 - precision_1: 0.4927 - recall_1: 0.7434 - roc_auc: 0.8757
# Epoch 137: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0376 - pr_auc: 0.6346 - precision_1: 0.4954 - recall_1: 0.7371 - roc_auc: 0.8778 - val_loss: 0.0384 - val_pr_auc: 0.6450 - val_precision_1: 0.5247 - val_recall_1: 0.7069 - val_roc_auc: 0.8758 - learning_rate: 2.5000e-04
# Epoch 138/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0382 - pr_auc: 0.6361 - precision_1: 0.5060 - recall_1: 0.7400 - roc_auc: 0.8743
# Epoch 138: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0373 - pr_auc: 0.6321 - precision_1: 0.5010 - recall_1: 0.7389 - roc_auc: 0.8789 - val_loss: 0.0378 - val_pr_auc: 0.6450 - val_precision_1: 0.4785 - val_recall_1: 0.7414 - val_roc_auc: 0.8766 - learning_rate: 1.2500e-04
# Epoch 139/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0371 - pr_auc: 0.6435 - precision_1: 0.5079 - recall_1: 0.7450 - roc_auc: 0.8819
# Epoch 139: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0371 - pr_auc: 0.6341 - precision_1: 0.5019 - recall_1: 0.7278 - roc_auc: 0.8787 - val_loss: 0.0379 - val_pr_auc: 0.6461 - val_precision_1: 0.4992 - val_recall_1: 0.7315 - val_roc_auc: 0.8766 - learning_rate: 1.2500e-04
# Epoch 140/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0372 - pr_auc: 0.6438 - precision_1: 0.5082 - recall_1: 0.7642 - roc_auc: 0.8866
# Epoch 140: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0370 - pr_auc: 0.6404 - precision_1: 0.4979 - recall_1: 0.7371 - roc_auc: 0.8804 - val_loss: 0.0381 - val_pr_auc: 0.6449 - val_precision_1: 0.5132 - val_recall_1: 0.7192 - val_roc_auc: 0.8753 - learning_rate: 1.2500e-04
# Epoch 141/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0351 - pr_auc: 0.6191 - precision_1: 0.4773 - recall_1: 0.7242 - roc_auc: 0.8829
# Epoch 141: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6401 - precision_1: 0.5013 - recall_1: 0.7358 - roc_auc: 0.8800 - val_loss: 0.0375 - val_pr_auc: 0.6463 - val_precision_1: 0.5070 - val_recall_1: 0.7143 - val_roc_auc: 0.8748 - learning_rate: 1.2500e-04
# Epoch 142/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0360 - pr_auc: 0.6597 - precision_1: 0.5215 - recall_1: 0.7383 - roc_auc: 0.8867
# Epoch 142: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0370 - pr_auc: 0.6441 - precision_1: 0.5023 - recall_1: 0.7389 - roc_auc: 0.8794 - val_loss: 0.0379 - val_pr_auc: 0.6464 - val_precision_1: 0.4886 - val_recall_1: 0.7365 - val_roc_auc: 0.8758 - learning_rate: 1.2500e-04
# Epoch 143/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6275 - precision_1: 0.4961 - recall_1: 0.7523 - roc_auc: 0.8754
# Epoch 143: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0370 - pr_auc: 0.6465 - precision_1: 0.5027 - recall_1: 0.7482 - roc_auc: 0.8808 - val_loss: 0.0383 - val_pr_auc: 0.6463 - val_precision_1: 0.4690 - val_recall_1: 0.7463 - val_roc_auc: 0.8755 - learning_rate: 1.2500e-04
# Epoch 144/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0367 - pr_auc: 0.6321 - precision_1: 0.4821 - recall_1: 0.7294 - roc_auc: 0.8765
# Epoch 144: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0370 - pr_auc: 0.6450 - precision_1: 0.4975 - recall_1: 0.7352 - roc_auc: 0.8799 - val_loss: 0.0386 - val_pr_auc: 0.6452 - val_precision_1: 0.4720 - val_recall_1: 0.7463 - val_roc_auc: 0.8750 - learning_rate: 1.2500e-04
# Epoch 145/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0366 - pr_auc: 0.6612 - precision_1: 0.5044 - recall_1: 0.7462 - roc_auc: 0.8879
# Epoch 145: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0368 - pr_auc: 0.6437 - precision_1: 0.5044 - recall_1: 0.7340 - roc_auc: 0.8815 - val_loss: 0.0382 - val_pr_auc: 0.6478 - val_precision_1: 0.4551 - val_recall_1: 0.7734 - val_roc_auc: 0.8758 - learning_rate: 1.2500e-04
# Epoch 146/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0386 - pr_auc: 0.6355 - precision_1: 0.4868 - recall_1: 0.7504 - roc_auc: 0.8743
# Epoch 146: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0369 - pr_auc: 0.6384 - precision_1: 0.4977 - recall_1: 0.7408 - roc_auc: 0.8811 - val_loss: 0.0392 - val_pr_auc: 0.6446 - val_precision_1: 0.4983 - val_recall_1: 0.7217 - val_roc_auc: 0.8747 - learning_rate: 1.2500e-04
# Epoch 147/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6567 - precision_1: 0.5090 - recall_1: 0.7462 - roc_auc: 0.8858
# Epoch 147: val_pr_auc did not improve from 0.65208
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0369 - pr_auc: 0.6462 - precision_1: 0.4990 - recall_1: 0.7395 - roc_auc: 0.8807 - val_loss: 0.0389 - val_pr_auc: 0.6471 - val_precision_1: 0.4983 - val_recall_1: 0.7340 - val_roc_auc: 0.8751 - learning_rate: 1.2500e-04

# %%
results = model1.evaluate(X_test, y_test, verbose=0, return_dict=True)
print(results)
# Out:
# {'loss': 0.03603631258010864, 'pr_auc': 0.6439892649650574, 'precision_1': 0.494579941034317, 'recall_1': 0.7199211120605469, 'roc_auc': 0.8797699809074402}

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['pr_auc'])
plt.plot(history.history['val_pr_auc'])
plt.title('PR-AUC')
plt.xlabel('Epoch')
plt.ylabel('PR-AUC')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.plot(history.history['roc_auc'])
plt.plot(history.history['val_roc_auc'])
plt.title('ROC-AUC')
plt.xlabel('Epoch')
plt.ylabel('ROC-AUC')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
from tensorflow.keras.models import load_model
import numpy as np

model1 = load_model("output/dna_focal.keras", compile=False)
predictions = model1.predict(X_test)  
predictions = predictions.flatten()    

predicted_labels = (predictions > 0.5).astype(int)
y_true = y_test.flatten().astype(int)

accuracy = (predicted_labels == y_true).mean()
print("Test Accuracy:", accuracy)
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
# Test Accuracy: 0.8314238952536824
