# %%
import imports
import split, model, weights, focal_train

# %%
import numpy as np

X = np.load("input/X.npy")
y = np.load("input/y.npy")

print(X.shape)  # (N, 90, 1)
print(y.shape)  # (N,)
# Out:
# (15272, 90, 1)
# (15272,)

# %%
X_train, X_val, X_test, y_train, y_val, y_test = split.stratified_split(X, y)

print("Train:", X_train.shape, y_train.shape)
print("Val:  ", X_val.shape, y_val.shape)
print("Test: ", X_test.shape, y_test.shape)
# Out:
# Train: (9773, 90, 1) (9773,)
# Val:   (2444, 90, 1) (2444,)
# Test:  (3055, 90, 1) (3055,)

# %%
print("Train class distribution:", np.bincount(y_train.astype(int)))
print("Val class distribution:", np.bincount(y_val.astype(int)))
print("Test class distribution:", np.bincount(y_test.astype(int)))
# Out:
# Train class distribution: [8149 1624]
# Val class distribution: [2038  406]
# Test class distribution: [2548  507]

# %%
print(y_train.shape)
# Out:
# (9773,)

# %%
import importlib
import model
importlib.reload(model)
# Out:
# <module 'model' from '/home/jupyter-22wh1a12a2/major_project/DNA/model.py'>

# %%
from model import build_model, compile_focal

model1 = build_model()
model = compile_focal(
    model1,
    alpha=0.75,
    gamma=2.0
)
model1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 90, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 90, 32)    │        128 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 90, 32)    │        192 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 90, 32)    │        256 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 90, 96)    │          0 │ conv1d_3[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_4[0][0],   │
# │                     │                   │            │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 45, 96)    │          0 │ concatenate_1[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     41,216 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      4,160 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 46,017 (179.75 KB)
#  Trainable params: 46,017 (179.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = focal_train.train_focal(model1, X_train, y_train, X_val, y_val)
# Out:
# Epoch 1/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0554 - pr_auc: 0.1578 - precision_1: 0.1034 - recall_1: 0.0149 - roc_auc: 0.4940
# Epoch 1: val_pr_auc improved from None to 0.25446, saving model to output/dna_pure_focal.keras
#
# Epoch 1: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 0.0555 - pr_auc: 0.1691 - precision_1: 0.1034 - recall_1: 0.0018 - roc_auc: 0.5129 - val_loss: 0.0551 - val_pr_auc: 0.2545 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_roc_auc: 0.6186 - learning_rate: 0.0010
# Epoch 2/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0536 - pr_auc: 0.2461 - precision_1: 0.2903 - recall_1: 0.1738 - roc_auc: 0.6327
# Epoch 2: val_pr_auc improved from 0.25446 to 0.49537, saving model to output/dna_pure_focal.keras
#
# Epoch 2: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0510 - pr_auc: 0.3154 - precision_1: 0.3380 - recall_1: 0.3282 - roc_auc: 0.6993 - val_loss: 0.0438 - val_pr_auc: 0.4954 - val_precision_1: 0.4234 - val_recall_1: 0.6059 - val_roc_auc: 0.8111 - learning_rate: 0.0010
# Epoch 3/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0465 - pr_auc: 0.3928 - precision_1: 0.3967 - recall_1: 0.5035 - roc_auc: 0.7713
# Epoch 3: val_pr_auc improved from 0.49537 to 0.57964, saving model to output/dna_pure_focal.keras
#
# Epoch 3: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0462 - pr_auc: 0.4306 - precision_1: 0.4140 - recall_1: 0.5437 - roc_auc: 0.7822 - val_loss: 0.0401 - val_pr_auc: 0.5796 - val_precision_1: 0.5914 - val_recall_1: 0.5739 - val_roc_auc: 0.8539 - learning_rate: 0.0010
# Epoch 4/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0445 - pr_auc: 0.5160 - precision_1: 0.4921 - recall_1: 0.5582 - roc_auc: 0.8086
# Epoch 4: val_pr_auc improved from 0.57964 to 0.58493, saving model to output/dna_pure_focal.keras
#
# Epoch 4: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0432 - pr_auc: 0.5226 - precision_1: 0.4877 - recall_1: 0.5850 - roc_auc: 0.8188 - val_loss: 0.0402 - val_pr_auc: 0.5849 - val_precision_1: 0.5269 - val_recall_1: 0.6749 - val_roc_auc: 0.8602 - learning_rate: 0.0010
# Epoch 5/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0427 - pr_auc: 0.5181 - precision_1: 0.4627 - recall_1: 0.6379 - roc_auc: 0.8234
# Epoch 5: val_pr_auc improved from 0.58493 to 0.58995, saving model to output/dna_pure_focal.keras
#
# Epoch 5: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0419 - pr_auc: 0.5318 - precision_1: 0.4729 - recall_1: 0.6349 - roc_auc: 0.8288 - val_loss: 0.0391 - val_pr_auc: 0.5899 - val_precision_1: 0.5866 - val_recall_1: 0.5837 - val_roc_auc: 0.8633 - learning_rate: 0.0010
# Epoch 6/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0409 - pr_auc: 0.5616 - precision_1: 0.4920 - recall_1: 0.6235 - roc_auc: 0.8421
# Epoch 6: val_pr_auc did not improve from 0.58995
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0415 - pr_auc: 0.5514 - precision_1: 0.4951 - recall_1: 0.6201 - roc_auc: 0.8346 - val_loss: 0.0389 - val_pr_auc: 0.5880 - val_precision_1: 0.4983 - val_recall_1: 0.7340 - val_roc_auc: 0.8645 - learning_rate: 0.0010
# Epoch 7/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0404 - pr_auc: 0.5453 - precision_1: 0.4742 - recall_1: 0.6240 - roc_auc: 0.8305
# Epoch 7: val_pr_auc improved from 0.58995 to 0.59767, saving model to output/dna_pure_focal.keras
#
# Epoch 7: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0414 - pr_auc: 0.5532 - precision_1: 0.4887 - recall_1: 0.6410 - roc_auc: 0.8336 - val_loss: 0.0389 - val_pr_auc: 0.5977 - val_precision_1: 0.5970 - val_recall_1: 0.5911 - val_roc_auc: 0.8656 - learning_rate: 0.0010
# Epoch 8/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0410 - pr_auc: 0.5410 - precision_1: 0.4961 - recall_1: 0.6444 - roc_auc: 0.8425
# Epoch 8: val_pr_auc did not improve from 0.59767
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0410 - pr_auc: 0.5465 - precision_1: 0.4902 - recall_1: 0.6466 - roc_auc: 0.8407 - val_loss: 0.0383 - val_pr_auc: 0.5971 - val_precision_1: 0.5307 - val_recall_1: 0.7020 - val_roc_auc: 0.8666 - learning_rate: 0.0010
# Epoch 9/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0414 - pr_auc: 0.5474 - precision_1: 0.4758 - recall_1: 0.6725 - roc_auc: 0.8420
# Epoch 9: val_pr_auc did not improve from 0.59767
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - loss: 0.0407 - pr_auc: 0.5409 - precision_1: 0.4759 - recall_1: 0.6675 - roc_auc: 0.8431 - val_loss: 0.0399 - val_pr_auc: 0.5976 - val_precision_1: 0.6093 - val_recall_1: 0.5493 - val_roc_auc: 0.8671 - learning_rate: 0.0010
# Epoch 10/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0417 - pr_auc: 0.5460 - precision_1: 0.5075 - recall_1: 0.5954 - roc_auc: 0.8276
# Epoch 10: val_pr_auc improved from 0.59767 to 0.59937, saving model to output/dna_pure_focal.keras
#
# Epoch 10: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - loss: 0.0412 - pr_auc: 0.5472 - precision_1: 0.4959 - recall_1: 0.6318 - roc_auc: 0.8378 - val_loss: 0.0381 - val_pr_auc: 0.5994 - val_precision_1: 0.5571 - val_recall_1: 0.6847 - val_roc_auc: 0.8671 - learning_rate: 0.0010
# Epoch 11/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0409 - pr_auc: 0.5563 - precision_1: 0.4738 - recall_1: 0.6238 - roc_auc: 0.8358
# Epoch 11: val_pr_auc did not improve from 0.59937
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - loss: 0.0408 - pr_auc: 0.5650 - precision_1: 0.4808 - recall_1: 0.6398 - roc_auc: 0.8408 - val_loss: 0.0385 - val_pr_auc: 0.5992 - val_precision_1: 0.5910 - val_recall_1: 0.5837 - val_roc_auc: 0.8677 - learning_rate: 0.0010
# Epoch 12/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0404 - pr_auc: 0.5661 - precision_1: 0.4979 - recall_1: 0.6297 - roc_auc: 0.8499
# Epoch 12: val_pr_auc improved from 0.59937 to 0.60146, saving model to output/dna_pure_focal.keras
#
# Epoch 12: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0404 - pr_auc: 0.5644 - precision_1: 0.4924 - recall_1: 0.6392 - roc_auc: 0.8450 - val_loss: 0.0397 - val_pr_auc: 0.6015 - val_precision_1: 0.4027 - val_recall_1: 0.8153 - val_roc_auc: 0.8670 - learning_rate: 0.0010
# Epoch 13/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0402 - pr_auc: 0.5634 - precision_1: 0.4733 - recall_1: 0.6574 - roc_auc: 0.8436
# Epoch 13: val_pr_auc improved from 0.60146 to 0.60856, saving model to output/dna_pure_focal.keras
#
# Epoch 13: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0405 - pr_auc: 0.5655 - precision_1: 0.4892 - recall_1: 0.6552 - roc_auc: 0.8432 - val_loss: 0.0376 - val_pr_auc: 0.6086 - val_precision_1: 0.5035 - val_recall_1: 0.7143 - val_roc_auc: 0.8686 - learning_rate: 0.0010
# Epoch 14/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0400 - pr_auc: 0.5744 - precision_1: 0.4994 - recall_1: 0.6443 - roc_auc: 0.8482
# Epoch 14: val_pr_auc did not improve from 0.60856
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0403 - pr_auc: 0.5706 - precision_1: 0.4949 - recall_1: 0.6533 - roc_auc: 0.8461 - val_loss: 0.0396 - val_pr_auc: 0.6066 - val_precision_1: 0.3812 - val_recall_1: 0.8374 - val_roc_auc: 0.8688 - learning_rate: 0.0010
# Epoch 15/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0394 - pr_auc: 0.5551 - precision_1: 0.4647 - recall_1: 0.6479 - roc_auc: 0.8471
# Epoch 15: val_pr_auc did not improve from 0.60856
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - loss: 0.0396 - pr_auc: 0.5737 - precision_1: 0.4893 - recall_1: 0.6595 - roc_auc: 0.8511 - val_loss: 0.0380 - val_pr_auc: 0.6045 - val_precision_1: 0.5769 - val_recall_1: 0.6650 - val_roc_auc: 0.8680 - learning_rate: 0.0010
# Epoch 16/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0405 - pr_auc: 0.5688 - precision_1: 0.4970 - recall_1: 0.6373 - roc_auc: 0.8439
# Epoch 16: val_pr_auc did not improve from 0.60856
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0403 - pr_auc: 0.5725 - precision_1: 0.4967 - recall_1: 0.6552 - roc_auc: 0.8464 - val_loss: 0.0400 - val_pr_auc: 0.6048 - val_precision_1: 0.3783 - val_recall_1: 0.8424 - val_roc_auc: 0.8690 - learning_rate: 0.0010
# Epoch 17/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0408 - pr_auc: 0.5755 - precision_1: 0.4872 - recall_1: 0.6542 - roc_auc: 0.8443
# Epoch 17: val_pr_auc did not improve from 0.60856
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0400 - pr_auc: 0.5746 - precision_1: 0.5002 - recall_1: 0.6515 - roc_auc: 0.8481 - val_loss: 0.0389 - val_pr_auc: 0.6061 - val_precision_1: 0.4246 - val_recall_1: 0.7906 - val_roc_auc: 0.8679 - learning_rate: 0.0010
# Epoch 18/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0407 - pr_auc: 0.5569 - precision_1: 0.4743 - recall_1: 0.6904 - roc_auc: 0.8445
# Epoch 18: val_pr_auc did not improve from 0.60856
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0399 - pr_auc: 0.5771 - precision_1: 0.4831 - recall_1: 0.6687 - roc_auc: 0.8484 - val_loss: 0.0393 - val_pr_auc: 0.6025 - val_precision_1: 0.4661 - val_recall_1: 0.7291 - val_roc_auc: 0.8631 - learning_rate: 0.0010
# Epoch 19/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0389 - pr_auc: 0.5691 - precision_1: 0.5220 - recall_1: 0.6647 - roc_auc: 0.8573
# Epoch 19: val_pr_auc did not improve from 0.60856
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0406 - pr_auc: 0.5547 - precision_1: 0.5019 - recall_1: 0.6509 - roc_auc: 0.8443 - val_loss: 0.0378 - val_pr_auc: 0.6060 - val_precision_1: 0.5584 - val_recall_1: 0.6946 - val_roc_auc: 0.8688 - learning_rate: 0.0010
# Epoch 20/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0400 - pr_auc: 0.5605 - precision_1: 0.4883 - recall_1: 0.6879 - roc_auc: 0.8498
# Epoch 20: val_pr_auc did not improve from 0.60856
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0400 - pr_auc: 0.5662 - precision_1: 0.4807 - recall_1: 0.6743 - roc_auc: 0.8497 - val_loss: 0.0382 - val_pr_auc: 0.6022 - val_precision_1: 0.5103 - val_recall_1: 0.7291 - val_roc_auc: 0.8665 - learning_rate: 0.0010
# Epoch 21/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0394 - pr_auc: 0.5620 - precision_1: 0.4710 - recall_1: 0.6541 - roc_auc: 0.8461
# Epoch 21: val_pr_auc improved from 0.60856 to 0.60913, saving model to output/dna_pure_focal.keras
#
# Epoch 21: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0401 - pr_auc: 0.5788 - precision_1: 0.4862 - recall_1: 0.6595 - roc_auc: 0.8472 - val_loss: 0.0385 - val_pr_auc: 0.6091 - val_precision_1: 0.5986 - val_recall_1: 0.6281 - val_roc_auc: 0.8697 - learning_rate: 0.0010
# Epoch 22/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0386 - pr_auc: 0.5774 - precision_1: 0.5006 - recall_1: 0.6309 - roc_auc: 0.8528
# Epoch 22: val_pr_auc did not improve from 0.60913
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0397 - pr_auc: 0.5826 - precision_1: 0.4877 - recall_1: 0.6607 - roc_auc: 0.8502 - val_loss: 0.0387 - val_pr_auc: 0.6083 - val_precision_1: 0.5519 - val_recall_1: 0.6946 - val_roc_auc: 0.8695 - learning_rate: 0.0010
# Epoch 23/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0399 - pr_auc: 0.5800 - precision_1: 0.4909 - recall_1: 0.6696 - roc_auc: 0.8518
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 23: val_pr_auc did not improve from 0.60913
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0395 - pr_auc: 0.5846 - precision_1: 0.4910 - recall_1: 0.6712 - roc_auc: 0.8517 - val_loss: 0.0388 - val_pr_auc: 0.6090 - val_precision_1: 0.6115 - val_recall_1: 0.5739 - val_roc_auc: 0.8695 - learning_rate: 0.0010
# Epoch 24/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0388 - pr_auc: 0.5958 - precision_1: 0.4931 - recall_1: 0.6474 - roc_auc: 0.8626
# Epoch 24: val_pr_auc improved from 0.60913 to 0.61035, saving model to output/dna_pure_focal.keras
#
# Epoch 24: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.5917 - precision_1: 0.4933 - recall_1: 0.6613 - roc_auc: 0.8549 - val_loss: 0.0384 - val_pr_auc: 0.6103 - val_precision_1: 0.4868 - val_recall_1: 0.7241 - val_roc_auc: 0.8702 - learning_rate: 5.0000e-04
# Epoch 25/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0402 - pr_auc: 0.5871 - precision_1: 0.4970 - recall_1: 0.6488 - roc_auc: 0.8488
# Epoch 25: val_pr_auc did not improve from 0.61035
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0391 - pr_auc: 0.5945 - precision_1: 0.4970 - recall_1: 0.6638 - roc_auc: 0.8550 - val_loss: 0.0381 - val_pr_auc: 0.6099 - val_precision_1: 0.5861 - val_recall_1: 0.6626 - val_roc_auc: 0.8703 - learning_rate: 5.0000e-04
# Epoch 26/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0376 - pr_auc: 0.6135 - precision_1: 0.4986 - recall_1: 0.6863 - roc_auc: 0.8683
# Epoch 26: val_pr_auc did not improve from 0.61035
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0387 - pr_auc: 0.5980 - precision_1: 0.4855 - recall_1: 0.6718 - roc_auc: 0.8586 - val_loss: 0.0391 - val_pr_auc: 0.6099 - val_precision_1: 0.4192 - val_recall_1: 0.8054 - val_roc_auc: 0.8694 - learning_rate: 5.0000e-04
# Epoch 27/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0396 - pr_auc: 0.5796 - precision_1: 0.4863 - recall_1: 0.6411 - roc_auc: 0.8503
# Epoch 27: val_pr_auc did not improve from 0.61035
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0392 - pr_auc: 0.5880 - precision_1: 0.4952 - recall_1: 0.6601 - roc_auc: 0.8544 - val_loss: 0.0381 - val_pr_auc: 0.6100 - val_precision_1: 0.5995 - val_recall_1: 0.6379 - val_roc_auc: 0.8696 - learning_rate: 5.0000e-04
# Epoch 28/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0388 - pr_auc: 0.5898 - precision_1: 0.4932 - recall_1: 0.6373 - roc_auc: 0.8557
# Epoch 28: val_pr_auc improved from 0.61035 to 0.61238, saving model to output/dna_pure_focal.keras
#
# Epoch 28: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0393 - pr_auc: 0.5885 - precision_1: 0.4947 - recall_1: 0.6644 - roc_auc: 0.8556 - val_loss: 0.0375 - val_pr_auc: 0.6124 - val_precision_1: 0.5247 - val_recall_1: 0.7069 - val_roc_auc: 0.8703 - learning_rate: 5.0000e-04
# Epoch 29/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0393 - pr_auc: 0.5944 - precision_1: 0.4954 - recall_1: 0.6749 - roc_auc: 0.8564
# Epoch 29: val_pr_auc improved from 0.61238 to 0.61264, saving model to output/dna_pure_focal.keras
#
# Epoch 29: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0389 - pr_auc: 0.5969 - precision_1: 0.4923 - recall_1: 0.6724 - roc_auc: 0.8579 - val_loss: 0.0388 - val_pr_auc: 0.6126 - val_precision_1: 0.5669 - val_recall_1: 0.6576 - val_roc_auc: 0.8698 - learning_rate: 5.0000e-04
# Epoch 30/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0393 - pr_auc: 0.6049 - precision_1: 0.5158 - recall_1: 0.6738 - roc_auc: 0.8586
# Epoch 30: val_pr_auc improved from 0.61264 to 0.61398, saving model to output/dna_pure_focal.keras
#
# Epoch 30: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0389 - pr_auc: 0.5955 - precision_1: 0.4941 - recall_1: 0.6755 - roc_auc: 0.8569 - val_loss: 0.0381 - val_pr_auc: 0.6140 - val_precision_1: 0.4983 - val_recall_1: 0.7241 - val_roc_auc: 0.8708 - learning_rate: 5.0000e-04
# Epoch 31/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0387 - pr_auc: 0.6069 - precision_1: 0.5019 - recall_1: 0.6630 - roc_auc: 0.8584
# Epoch 31: val_pr_auc did not improve from 0.61398
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0390 - pr_auc: 0.5994 - precision_1: 0.4945 - recall_1: 0.6626 - roc_auc: 0.8563 - val_loss: 0.0379 - val_pr_auc: 0.6136 - val_precision_1: 0.5151 - val_recall_1: 0.7143 - val_roc_auc: 0.8707 - learning_rate: 5.0000e-04
# Epoch 32/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6143 - precision_1: 0.5071 - recall_1: 0.6859 - roc_auc: 0.8659
# Epoch 32: val_pr_auc improved from 0.61398 to 0.61562, saving model to output/dna_pure_focal.keras
#
# Epoch 32: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0389 - pr_auc: 0.5958 - precision_1: 0.5032 - recall_1: 0.6761 - roc_auc: 0.8573 - val_loss: 0.0378 - val_pr_auc: 0.6156 - val_precision_1: 0.4902 - val_recall_1: 0.7365 - val_roc_auc: 0.8710 - learning_rate: 5.0000e-04
# Epoch 33/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - pr_auc: 0.6067 - precision_1: 0.5091 - recall_1: 0.6667 - roc_auc: 0.8604
# Epoch 33: val_pr_auc did not improve from 0.61562
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0390 - pr_auc: 0.5960 - precision_1: 0.5014 - recall_1: 0.6576 - roc_auc: 0.8570 - val_loss: 0.0384 - val_pr_auc: 0.6153 - val_precision_1: 0.4590 - val_recall_1: 0.7586 - val_roc_auc: 0.8708 - learning_rate: 5.0000e-04
# Epoch 34/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - pr_auc: 0.5732 - precision_1: 0.4882 - recall_1: 0.6560 - roc_auc: 0.8544
# Epoch 34: val_pr_auc improved from 0.61562 to 0.61599, saving model to output/dna_pure_focal.keras
#
# Epoch 34: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0389 - pr_auc: 0.5925 - precision_1: 0.5019 - recall_1: 0.6583 - roc_auc: 0.8574 - val_loss: 0.0377 - val_pr_auc: 0.6160 - val_precision_1: 0.5664 - val_recall_1: 0.6724 - val_roc_auc: 0.8704 - learning_rate: 5.0000e-04
# Epoch 35/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0389 - pr_auc: 0.5969 - precision_1: 0.5089 - recall_1: 0.6601 - roc_auc: 0.8519
# Epoch 35: val_pr_auc improved from 0.61599 to 0.61655, saving model to output/dna_pure_focal.keras
#
# Epoch 35: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0389 - pr_auc: 0.6002 - precision_1: 0.5032 - recall_1: 0.6681 - roc_auc: 0.8569 - val_loss: 0.0386 - val_pr_auc: 0.6165 - val_precision_1: 0.4423 - val_recall_1: 0.7833 - val_roc_auc: 0.8706 - learning_rate: 5.0000e-04
# Epoch 36/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0396 - pr_auc: 0.5826 - precision_1: 0.4840 - recall_1: 0.6654 - roc_auc: 0.8499
# Epoch 36: val_pr_auc improved from 0.61655 to 0.61737, saving model to output/dna_pure_focal.keras
#
# Epoch 36: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0388 - pr_auc: 0.5963 - precision_1: 0.5016 - recall_1: 0.6669 - roc_auc: 0.8579 - val_loss: 0.0389 - val_pr_auc: 0.6174 - val_precision_1: 0.4682 - val_recall_1: 0.7438 - val_roc_auc: 0.8703 - learning_rate: 5.0000e-04
# Epoch 37/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.6141 - precision_1: 0.5203 - recall_1: 0.6401 - roc_auc: 0.8574
# Epoch 37: val_pr_auc did not improve from 0.61737
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0389 - pr_auc: 0.6018 - precision_1: 0.5057 - recall_1: 0.6533 - roc_auc: 0.8578 - val_loss: 0.0376 - val_pr_auc: 0.6168 - val_precision_1: 0.5190 - val_recall_1: 0.7069 - val_roc_auc: 0.8711 - learning_rate: 5.0000e-04
# Epoch 38/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.5992 - precision_1: 0.4909 - recall_1: 0.6836 - roc_auc: 0.8596
# Epoch 38: val_pr_auc improved from 0.61737 to 0.61957, saving model to output/dna_pure_focal.keras
#
# Epoch 38: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0389 - pr_auc: 0.5944 - precision_1: 0.4984 - recall_1: 0.6595 - roc_auc: 0.8574 - val_loss: 0.0384 - val_pr_auc: 0.6196 - val_precision_1: 0.4430 - val_recall_1: 0.7759 - val_roc_auc: 0.8718 - learning_rate: 5.0000e-04
# Epoch 39/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0386 - pr_auc: 0.6055 - precision_1: 0.5115 - recall_1: 0.6795 - roc_auc: 0.8612
# Epoch 39: val_pr_auc improved from 0.61957 to 0.63069, saving model to output/dna_pure_focal.keras
#
# Epoch 39: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0386 - pr_auc: 0.6039 - precision_1: 0.5012 - recall_1: 0.6663 - roc_auc: 0.8602 - val_loss: 0.0382 - val_pr_auc: 0.6307 - val_precision_1: 0.5796 - val_recall_1: 0.6724 - val_roc_auc: 0.8717 - learning_rate: 5.0000e-04
# Epoch 40/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0388 - pr_auc: 0.6004 - precision_1: 0.5078 - recall_1: 0.6667 - roc_auc: 0.8602
# Epoch 40: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0389 - pr_auc: 0.5960 - precision_1: 0.5097 - recall_1: 0.6613 - roc_auc: 0.8584 - val_loss: 0.0375 - val_pr_auc: 0.6243 - val_precision_1: 0.5150 - val_recall_1: 0.7192 - val_roc_auc: 0.8720 - learning_rate: 5.0000e-04
# Epoch 41/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0393 - pr_auc: 0.5694 - precision_1: 0.5002 - recall_1: 0.6602 - roc_auc: 0.8510
# Epoch 41: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0389 - pr_auc: 0.5934 - precision_1: 0.5030 - recall_1: 0.6656 - roc_auc: 0.8573 - val_loss: 0.0376 - val_pr_auc: 0.6209 - val_precision_1: 0.5202 - val_recall_1: 0.6970 - val_roc_auc: 0.8719 - learning_rate: 5.0000e-04
# Epoch 42/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0378 - pr_auc: 0.5986 - precision_1: 0.4915 - recall_1: 0.6576 - roc_auc: 0.8648
# Epoch 42: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0385 - pr_auc: 0.5998 - precision_1: 0.4984 - recall_1: 0.6546 - roc_auc: 0.8603 - val_loss: 0.0378 - val_pr_auc: 0.6196 - val_precision_1: 0.6077 - val_recall_1: 0.6256 - val_roc_auc: 0.8709 - learning_rate: 5.0000e-04
# Epoch 43/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0389 - pr_auc: 0.5914 - precision_1: 0.5087 - recall_1: 0.6502 - roc_auc: 0.8577
# Epoch 43: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0388 - pr_auc: 0.5925 - precision_1: 0.5068 - recall_1: 0.6681 - roc_auc: 0.8595 - val_loss: 0.0372 - val_pr_auc: 0.6231 - val_precision_1: 0.5405 - val_recall_1: 0.6897 - val_roc_auc: 0.8716 - learning_rate: 5.0000e-04
# Epoch 44/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0383 - pr_auc: 0.6065 - precision_1: 0.5183 - recall_1: 0.6446 - roc_auc: 0.8615
# Epoch 44: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0385 - pr_auc: 0.6086 - precision_1: 0.5139 - recall_1: 0.6583 - roc_auc: 0.8608 - val_loss: 0.0382 - val_pr_auc: 0.6169 - val_precision_1: 0.5844 - val_recall_1: 0.6478 - val_roc_auc: 0.8684 - learning_rate: 5.0000e-04
# Epoch 45/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.5857 - precision_1: 0.4940 - recall_1: 0.6549 - roc_auc: 0.8552
# Epoch 45: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0387 - pr_auc: 0.5979 - precision_1: 0.5072 - recall_1: 0.6521 - roc_auc: 0.8585 - val_loss: 0.0375 - val_pr_auc: 0.6235 - val_precision_1: 0.5501 - val_recall_1: 0.6897 - val_roc_auc: 0.8719 - learning_rate: 5.0000e-04
# Epoch 46/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0378 - pr_auc: 0.6066 - precision_1: 0.5050 - recall_1: 0.6717 - roc_auc: 0.8664
# Epoch 46: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0386 - pr_auc: 0.5985 - precision_1: 0.4970 - recall_1: 0.6681 - roc_auc: 0.8595 - val_loss: 0.0378 - val_pr_auc: 0.6217 - val_precision_1: 0.5536 - val_recall_1: 0.6872 - val_roc_auc: 0.8718 - learning_rate: 5.0000e-04
# Epoch 47/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.6019 - precision_1: 0.5234 - recall_1: 0.6481 - roc_auc: 0.8530
# Epoch 47: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0385 - pr_auc: 0.6026 - precision_1: 0.5071 - recall_1: 0.6626 - roc_auc: 0.8603 - val_loss: 0.0376 - val_pr_auc: 0.6240 - val_precision_1: 0.4877 - val_recall_1: 0.7340 - val_roc_auc: 0.8721 - learning_rate: 5.0000e-04
# Epoch 48/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0377 - pr_auc: 0.6046 - precision_1: 0.5165 - recall_1: 0.6650 - roc_auc: 0.8651
# Epoch 48: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0388 - pr_auc: 0.5998 - precision_1: 0.5014 - recall_1: 0.6601 - roc_auc: 0.8592 - val_loss: 0.0379 - val_pr_auc: 0.6236 - val_precision_1: 0.4701 - val_recall_1: 0.7365 - val_roc_auc: 0.8714 - learning_rate: 5.0000e-04
# Epoch 49/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0386 - pr_auc: 0.5987 - precision_1: 0.5000 - recall_1: 0.6769 - roc_auc: 0.8597
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 49: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0386 - pr_auc: 0.6041 - precision_1: 0.5059 - recall_1: 0.6626 - roc_auc: 0.8593 - val_loss: 0.0375 - val_pr_auc: 0.6254 - val_precision_1: 0.5209 - val_recall_1: 0.7044 - val_roc_auc: 0.8724 - learning_rate: 5.0000e-04
# Epoch 50/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6093 - precision_1: 0.5118 - recall_1: 0.6599 - roc_auc: 0.8603
# Epoch 50: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0381 - pr_auc: 0.6127 - precision_1: 0.5074 - recall_1: 0.6792 - roc_auc: 0.8643 - val_loss: 0.0376 - val_pr_auc: 0.6247 - val_precision_1: 0.5009 - val_recall_1: 0.7192 - val_roc_auc: 0.8726 - learning_rate: 2.5000e-04
# Epoch 51/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0383 - pr_auc: 0.6203 - precision_1: 0.5073 - recall_1: 0.6702 - roc_auc: 0.8659
# Epoch 51: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6082 - precision_1: 0.5054 - recall_1: 0.6650 - roc_auc: 0.8634 - val_loss: 0.0379 - val_pr_auc: 0.6287 - val_precision_1: 0.6128 - val_recall_1: 0.6355 - val_roc_auc: 0.8728 - learning_rate: 2.5000e-04
# Epoch 52/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0388 - pr_auc: 0.5913 - precision_1: 0.4926 - recall_1: 0.6511 - roc_auc: 0.8566
# Epoch 52: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0380 - pr_auc: 0.6140 - precision_1: 0.5117 - recall_1: 0.6576 - roc_auc: 0.8640 - val_loss: 0.0376 - val_pr_auc: 0.6306 - val_precision_1: 0.5277 - val_recall_1: 0.7044 - val_roc_auc: 0.8723 - learning_rate: 2.5000e-04
# Epoch 53/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6157 - precision_1: 0.5165 - recall_1: 0.6668 - roc_auc: 0.8620
# Epoch 53: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6094 - precision_1: 0.5096 - recall_1: 0.6718 - roc_auc: 0.8642 - val_loss: 0.0384 - val_pr_auc: 0.6277 - val_precision_1: 0.6266 - val_recall_1: 0.6158 - val_roc_auc: 0.8721 - learning_rate: 2.5000e-04
# Epoch 54/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6344 - precision_1: 0.5385 - recall_1: 0.6751 - roc_auc: 0.8693
# Epoch 54: val_pr_auc did not improve from 0.63069
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6106 - precision_1: 0.5179 - recall_1: 0.6681 - roc_auc: 0.8636 - val_loss: 0.0380 - val_pr_auc: 0.6275 - val_precision_1: 0.6005 - val_recall_1: 0.6404 - val_roc_auc: 0.8720 - learning_rate: 2.5000e-04
# Epoch 55/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0381 - pr_auc: 0.6219 - precision_1: 0.5256 - recall_1: 0.6778 - roc_auc: 0.8685
# Epoch 55: val_pr_auc improved from 0.63069 to 0.63476, saving model to output/dna_pure_focal.keras
#
# Epoch 55: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0381 - pr_auc: 0.6124 - precision_1: 0.5173 - recall_1: 0.6718 - roc_auc: 0.8648 - val_loss: 0.0379 - val_pr_auc: 0.6348 - val_precision_1: 0.6084 - val_recall_1: 0.6429 - val_roc_auc: 0.8726 - learning_rate: 2.5000e-04
# Epoch 56/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - pr_auc: 0.5979 - precision_1: 0.5202 - recall_1: 0.6441 - roc_auc: 0.8574
# Epoch 56: val_pr_auc did not improve from 0.63476
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6142 - precision_1: 0.5218 - recall_1: 0.6558 - roc_auc: 0.8656 - val_loss: 0.0379 - val_pr_auc: 0.6291 - val_precision_1: 0.5190 - val_recall_1: 0.7069 - val_roc_auc: 0.8719 - learning_rate: 2.5000e-04
# Epoch 57/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - pr_auc: 0.6071 - precision_1: 0.5151 - recall_1: 0.6771 - roc_auc: 0.8625
# Epoch 57: val_pr_auc improved from 0.63476 to 0.63659, saving model to output/dna_pure_focal.keras
#
# Epoch 57: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0382 - pr_auc: 0.6096 - precision_1: 0.5146 - recall_1: 0.6749 - roc_auc: 0.8639 - val_loss: 0.0375 - val_pr_auc: 0.6366 - val_precision_1: 0.4893 - val_recall_1: 0.7340 - val_roc_auc: 0.8726 - learning_rate: 2.5000e-04
# Epoch 58/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - pr_auc: 0.6033 - precision_1: 0.4939 - recall_1: 0.6194 - roc_auc: 0.8518
# Epoch 58: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6218 - precision_1: 0.5154 - recall_1: 0.6607 - roc_auc: 0.8652 - val_loss: 0.0378 - val_pr_auc: 0.6331 - val_precision_1: 0.5434 - val_recall_1: 0.6946 - val_roc_auc: 0.8724 - learning_rate: 2.5000e-04
# Epoch 59/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0374 - pr_auc: 0.6299 - precision_1: 0.5439 - recall_1: 0.6688 - roc_auc: 0.8692
# Epoch 59: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6169 - precision_1: 0.5261 - recall_1: 0.6527 - roc_auc: 0.8659 - val_loss: 0.0377 - val_pr_auc: 0.6354 - val_precision_1: 0.5179 - val_recall_1: 0.7143 - val_roc_auc: 0.8730 - learning_rate: 2.5000e-04
# Epoch 60/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0385 - pr_auc: 0.6092 - precision_1: 0.5226 - recall_1: 0.6775 - roc_auc: 0.8638
# Epoch 60: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0381 - pr_auc: 0.6106 - precision_1: 0.5211 - recall_1: 0.6693 - roc_auc: 0.8641 - val_loss: 0.0382 - val_pr_auc: 0.6318 - val_precision_1: 0.5723 - val_recall_1: 0.6724 - val_roc_auc: 0.8723 - learning_rate: 2.5000e-04
# Epoch 61/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0381 - pr_auc: 0.5879 - precision_1: 0.5132 - recall_1: 0.6381 - roc_auc: 0.8562
# Epoch 61: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6176 - precision_1: 0.5157 - recall_1: 0.6681 - roc_auc: 0.8658 - val_loss: 0.0373 - val_pr_auc: 0.6324 - val_precision_1: 0.5624 - val_recall_1: 0.6773 - val_roc_auc: 0.8729 - learning_rate: 2.5000e-04
# Epoch 62/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0378 - pr_auc: 0.5990 - precision_1: 0.5116 - recall_1: 0.6499 - roc_auc: 0.8578
# Epoch 62: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0381 - pr_auc: 0.6122 - precision_1: 0.5229 - recall_1: 0.6552 - roc_auc: 0.8630 - val_loss: 0.0381 - val_pr_auc: 0.6332 - val_precision_1: 0.5179 - val_recall_1: 0.7118 - val_roc_auc: 0.8727 - learning_rate: 2.5000e-04
# Epoch 63/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0379 - pr_auc: 0.6103 - precision_1: 0.4964 - recall_1: 0.6745 - roc_auc: 0.8646
# Epoch 63: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6148 - precision_1: 0.5046 - recall_1: 0.6743 - roc_auc: 0.8660 - val_loss: 0.0374 - val_pr_auc: 0.6313 - val_precision_1: 0.5596 - val_recall_1: 0.6823 - val_roc_auc: 0.8731 - learning_rate: 2.5000e-04
# Epoch 64/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6210 - precision_1: 0.5274 - recall_1: 0.6828 - roc_auc: 0.8691
# Epoch 64: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0380 - pr_auc: 0.6142 - precision_1: 0.5266 - recall_1: 0.6700 - roc_auc: 0.8651 - val_loss: 0.0376 - val_pr_auc: 0.6321 - val_precision_1: 0.5369 - val_recall_1: 0.6995 - val_roc_auc: 0.8727 - learning_rate: 2.5000e-04
# Epoch 65/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0372 - pr_auc: 0.6101 - precision_1: 0.5273 - recall_1: 0.6751 - roc_auc: 0.8665
# Epoch 65: val_pr_auc did not improve from 0.63659
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6138 - precision_1: 0.5222 - recall_1: 0.6743 - roc_auc: 0.8645 - val_loss: 0.0379 - val_pr_auc: 0.6308 - val_precision_1: 0.5941 - val_recall_1: 0.6453 - val_roc_auc: 0.8719 - learning_rate: 2.5000e-04
# Epoch 66/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - pr_auc: 0.6206 - precision_1: 0.5222 - recall_1: 0.6551 - roc_auc: 0.8649
# Epoch 66: val_pr_auc improved from 0.63659 to 0.64035, saving model to output/dna_pure_focal.keras
#
# Epoch 66: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0381 - pr_auc: 0.6091 - precision_1: 0.5187 - recall_1: 0.6589 - roc_auc: 0.8644 - val_loss: 0.0371 - val_pr_auc: 0.6404 - val_precision_1: 0.5133 - val_recall_1: 0.7118 - val_roc_auc: 0.8724 - learning_rate: 2.5000e-04
# Epoch 67/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0383 - pr_auc: 0.6060 - precision_1: 0.4999 - recall_1: 0.6663 - roc_auc: 0.8638
# Epoch 67: val_pr_auc did not improve from 0.64035
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6177 - precision_1: 0.5113 - recall_1: 0.6700 - roc_auc: 0.8654 - val_loss: 0.0374 - val_pr_auc: 0.6356 - val_precision_1: 0.5794 - val_recall_1: 0.6650 - val_roc_auc: 0.8725 - learning_rate: 2.5000e-04
# Epoch 68/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0379 - pr_auc: 0.5960 - precision_1: 0.4980 - recall_1: 0.6339 - roc_auc: 0.8626
# Epoch 68: val_pr_auc did not improve from 0.64035
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6146 - precision_1: 0.5207 - recall_1: 0.6576 - roc_auc: 0.8674 - val_loss: 0.0380 - val_pr_auc: 0.6221 - val_precision_1: 0.4598 - val_recall_1: 0.7463 - val_roc_auc: 0.8723 - learning_rate: 2.5000e-04
# Epoch 69/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0372 - pr_auc: 0.6090 - precision_1: 0.5122 - recall_1: 0.6584 - roc_auc: 0.8635
# Epoch 69: val_pr_auc did not improve from 0.64035
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6129 - precision_1: 0.5194 - recall_1: 0.6681 - roc_auc: 0.8651 - val_loss: 0.0382 - val_pr_auc: 0.6315 - val_precision_1: 0.5708 - val_recall_1: 0.6650 - val_roc_auc: 0.8721 - learning_rate: 2.5000e-04
# Epoch 70/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6009 - precision_1: 0.5042 - recall_1: 0.6560 - roc_auc: 0.8668
# Epoch 70: val_pr_auc improved from 0.64035 to 0.64185, saving model to output/dna_pure_focal.keras
#
# Epoch 70: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6175 - precision_1: 0.5214 - recall_1: 0.6601 - roc_auc: 0.8661 - val_loss: 0.0384 - val_pr_auc: 0.6418 - val_precision_1: 0.5009 - val_recall_1: 0.7241 - val_roc_auc: 0.8725 - learning_rate: 2.5000e-04
# Epoch 71/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.5885 - precision_1: 0.4888 - recall_1: 0.6261 - roc_auc: 0.8560
# Epoch 71: val_pr_auc did not improve from 0.64185
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6186 - precision_1: 0.5138 - recall_1: 0.6644 - roc_auc: 0.8670 - val_loss: 0.0384 - val_pr_auc: 0.6358 - val_precision_1: 0.5720 - val_recall_1: 0.6847 - val_roc_auc: 0.8720 - learning_rate: 2.5000e-04
# Epoch 72/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - pr_auc: 0.6114 - precision_1: 0.5290 - recall_1: 0.6600 - roc_auc: 0.8652
# Epoch 72: val_pr_auc did not improve from 0.64185
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0380 - pr_auc: 0.6108 - precision_1: 0.5185 - recall_1: 0.6570 - roc_auc: 0.8637 - val_loss: 0.0375 - val_pr_auc: 0.6352 - val_precision_1: 0.5508 - val_recall_1: 0.6946 - val_roc_auc: 0.8729 - learning_rate: 2.5000e-04
# Epoch 73/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0379 - pr_auc: 0.6213 - precision_1: 0.5203 - recall_1: 0.6508 - roc_auc: 0.8636
# Epoch 73: val_pr_auc did not improve from 0.64185
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0381 - pr_auc: 0.6179 - precision_1: 0.5213 - recall_1: 0.6644 - roc_auc: 0.8646 - val_loss: 0.0371 - val_pr_auc: 0.6342 - val_precision_1: 0.5308 - val_recall_1: 0.6995 - val_roc_auc: 0.8719 - learning_rate: 2.5000e-04
# Epoch 74/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - pr_auc: 0.6125 - precision_1: 0.5221 - recall_1: 0.6781 - roc_auc: 0.8651
# Epoch 74: val_pr_auc improved from 0.64185 to 0.64366, saving model to output/dna_pure_focal.keras
#
# Epoch 74: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6152 - precision_1: 0.5239 - recall_1: 0.6675 - roc_auc: 0.8662 - val_loss: 0.0377 - val_pr_auc: 0.6437 - val_precision_1: 0.4581 - val_recall_1: 0.7537 - val_roc_auc: 0.8730 - learning_rate: 2.5000e-04
# Epoch 75/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6365 - precision_1: 0.5119 - recall_1: 0.7017 - roc_auc: 0.8746
# Epoch 75: val_pr_auc did not improve from 0.64366
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6190 - precision_1: 0.5116 - recall_1: 0.6786 - roc_auc: 0.8656 - val_loss: 0.0382 - val_pr_auc: 0.6388 - val_precision_1: 0.5982 - val_recall_1: 0.6453 - val_roc_auc: 0.8723 - learning_rate: 2.5000e-04
# Epoch 76/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0376 - pr_auc: 0.6262 - precision_1: 0.5442 - recall_1: 0.6544 - roc_auc: 0.8690
# Epoch 76: val_pr_auc did not improve from 0.64366
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6218 - precision_1: 0.5300 - recall_1: 0.6589 - roc_auc: 0.8667 - val_loss: 0.0372 - val_pr_auc: 0.6368 - val_precision_1: 0.5132 - val_recall_1: 0.7167 - val_roc_auc: 0.8728 - learning_rate: 2.5000e-04
# Epoch 77/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0380 - pr_auc: 0.6254 - precision_1: 0.5228 - recall_1: 0.6831 - roc_auc: 0.8639
# Epoch 77: val_pr_auc did not improve from 0.64366
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6202 - precision_1: 0.5194 - recall_1: 0.6743 - roc_auc: 0.8650 - val_loss: 0.0379 - val_pr_auc: 0.6412 - val_precision_1: 0.5708 - val_recall_1: 0.6650 - val_roc_auc: 0.8716 - learning_rate: 2.5000e-04
# Epoch 78/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0373 - pr_auc: 0.6352 - precision_1: 0.5416 - recall_1: 0.6765 - roc_auc: 0.8682
# Epoch 78: val_pr_auc improved from 0.64366 to 0.64433, saving model to output/dna_pure_focal.keras
#
# Epoch 78: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0379 - pr_auc: 0.6178 - precision_1: 0.5241 - recall_1: 0.6755 - roc_auc: 0.8661 - val_loss: 0.0372 - val_pr_auc: 0.6443 - val_precision_1: 0.5117 - val_recall_1: 0.7020 - val_roc_auc: 0.8727 - learning_rate: 2.5000e-04
# Epoch 79/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6256 - precision_1: 0.5227 - recall_1: 0.6625 - roc_auc: 0.8676
# Epoch 79: val_pr_auc improved from 0.64433 to 0.64483, saving model to output/dna_pure_focal.keras
#
# Epoch 79: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6169 - precision_1: 0.5226 - recall_1: 0.6773 - roc_auc: 0.8670 - val_loss: 0.0374 - val_pr_auc: 0.6448 - val_precision_1: 0.5545 - val_recall_1: 0.6897 - val_roc_auc: 0.8730 - learning_rate: 2.5000e-04
# Epoch 80/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6063 - precision_1: 0.5124 - recall_1: 0.6825 - roc_auc: 0.8695
# Epoch 80: val_pr_auc did not improve from 0.64483
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0380 - pr_auc: 0.6145 - precision_1: 0.5131 - recall_1: 0.6749 - roc_auc: 0.8643 - val_loss: 0.0377 - val_pr_auc: 0.6356 - val_precision_1: 0.4942 - val_recall_1: 0.7340 - val_roc_auc: 0.8731 - learning_rate: 2.5000e-04
# Epoch 81/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0374 - pr_auc: 0.6203 - precision_1: 0.5151 - recall_1: 0.6721 - roc_auc: 0.8692
# Epoch 81: val_pr_auc did not improve from 0.64483
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6164 - precision_1: 0.5158 - recall_1: 0.6650 - roc_auc: 0.8665 - val_loss: 0.0374 - val_pr_auc: 0.6358 - val_precision_1: 0.5643 - val_recall_1: 0.6700 - val_roc_auc: 0.8723 - learning_rate: 2.5000e-04
# Epoch 82/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6354 - precision_1: 0.5274 - recall_1: 0.6927 - roc_auc: 0.8727
# Epoch 82: val_pr_auc did not improve from 0.64483
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6218 - precision_1: 0.5146 - recall_1: 0.6743 - roc_auc: 0.8669 - val_loss: 0.0371 - val_pr_auc: 0.6389 - val_precision_1: 0.5035 - val_recall_1: 0.7143 - val_roc_auc: 0.8731 - learning_rate: 2.5000e-04
# Epoch 83/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0386 - pr_auc: 0.6303 - precision_1: 0.5154 - recall_1: 0.6766 - roc_auc: 0.8650
# Epoch 83: val_pr_auc improved from 0.64483 to 0.64723, saving model to output/dna_pure_focal.keras
#
# Epoch 83: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0377 - pr_auc: 0.6263 - precision_1: 0.5127 - recall_1: 0.6712 - roc_auc: 0.8674 - val_loss: 0.0369 - val_pr_auc: 0.6472 - val_precision_1: 0.5644 - val_recall_1: 0.6798 - val_roc_auc: 0.8736 - learning_rate: 2.5000e-04
# Epoch 84/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - pr_auc: 0.6228 - precision_1: 0.5254 - recall_1: 0.6844 - roc_auc: 0.8674
# Epoch 84: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0376 - pr_auc: 0.6208 - precision_1: 0.5159 - recall_1: 0.6693 - roc_auc: 0.8678 - val_loss: 0.0377 - val_pr_auc: 0.6454 - val_precision_1: 0.5858 - val_recall_1: 0.6724 - val_roc_auc: 0.8729 - learning_rate: 2.5000e-04
# Epoch 85/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0385 - pr_auc: 0.6182 - precision_1: 0.5184 - recall_1: 0.6647 - roc_auc: 0.8614
# Epoch 85: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6152 - precision_1: 0.5229 - recall_1: 0.6749 - roc_auc: 0.8659 - val_loss: 0.0378 - val_pr_auc: 0.6427 - val_precision_1: 0.5717 - val_recall_1: 0.6773 - val_roc_auc: 0.8732 - learning_rate: 2.5000e-04
# Epoch 86/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6328 - precision_1: 0.5272 - recall_1: 0.6832 - roc_auc: 0.8675
# Epoch 86: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6162 - precision_1: 0.5140 - recall_1: 0.6767 - roc_auc: 0.8664 - val_loss: 0.0380 - val_pr_auc: 0.6429 - val_precision_1: 0.6014 - val_recall_1: 0.6502 - val_roc_auc: 0.8730 - learning_rate: 2.5000e-04
# Epoch 87/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0384 - pr_auc: 0.6250 - precision_1: 0.5408 - recall_1: 0.6684 - roc_auc: 0.8647
# Epoch 87: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6139 - precision_1: 0.5172 - recall_1: 0.6767 - roc_auc: 0.8658 - val_loss: 0.0371 - val_pr_auc: 0.6380 - val_precision_1: 0.5501 - val_recall_1: 0.6897 - val_roc_auc: 0.8730 - learning_rate: 2.5000e-04
# Epoch 88/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - pr_auc: 0.6122 - precision_1: 0.5233 - recall_1: 0.6598 - roc_auc: 0.8660
# Epoch 88: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6112 - precision_1: 0.5199 - recall_1: 0.6681 - roc_auc: 0.8667 - val_loss: 0.0381 - val_pr_auc: 0.6440 - val_precision_1: 0.4856 - val_recall_1: 0.7463 - val_roc_auc: 0.8726 - learning_rate: 2.5000e-04
# Epoch 89/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0380 - pr_auc: 0.6222 - precision_1: 0.5254 - recall_1: 0.6763 - roc_auc: 0.8678
# Epoch 89: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6174 - precision_1: 0.5311 - recall_1: 0.6669 - roc_auc: 0.8663 - val_loss: 0.0377 - val_pr_auc: 0.6468 - val_precision_1: 0.5152 - val_recall_1: 0.7094 - val_roc_auc: 0.8730 - learning_rate: 2.5000e-04
# Epoch 90/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - pr_auc: 0.6042 - precision_1: 0.5070 - recall_1: 0.6710 - roc_auc: 0.8563
# Epoch 90: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6175 - precision_1: 0.5133 - recall_1: 0.6792 - roc_auc: 0.8668 - val_loss: 0.0411 - val_pr_auc: 0.6438 - val_precision_1: 0.6855 - val_recall_1: 0.5369 - val_roc_auc: 0.8720 - learning_rate: 2.5000e-04
# Epoch 91/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0385 - pr_auc: 0.6106 - precision_1: 0.5045 - recall_1: 0.6445 - roc_auc: 0.8605
# Epoch 91: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0379 - pr_auc: 0.6187 - precision_1: 0.5094 - recall_1: 0.6650 - roc_auc: 0.8654 - val_loss: 0.0378 - val_pr_auc: 0.6401 - val_precision_1: 0.6037 - val_recall_1: 0.6379 - val_roc_auc: 0.8727 - learning_rate: 2.5000e-04
# Epoch 92/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0373 - pr_auc: 0.6237 - precision_1: 0.5412 - recall_1: 0.6872 - roc_auc: 0.8746
# Epoch 92: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0378 - pr_auc: 0.6145 - precision_1: 0.5241 - recall_1: 0.6564 - roc_auc: 0.8655 - val_loss: 0.0392 - val_pr_auc: 0.6443 - val_precision_1: 0.6199 - val_recall_1: 0.6305 - val_roc_auc: 0.8732 - learning_rate: 2.5000e-04
# Epoch 93/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0374 - pr_auc: 0.6233 - precision_1: 0.5162 - recall_1: 0.6477 - roc_auc: 0.8670
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 93: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0377 - pr_auc: 0.6239 - precision_1: 0.5177 - recall_1: 0.6570 - roc_auc: 0.8665 - val_loss: 0.0386 - val_pr_auc: 0.6440 - val_precision_1: 0.5882 - val_recall_1: 0.6650 - val_roc_auc: 0.8727 - learning_rate: 2.5000e-04
# Epoch 94/200
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0371 - pr_auc: 0.6262 - precision_1: 0.5262 - recall_1: 0.6908 - roc_auc: 0.8730
# Epoch 94: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6232 - precision_1: 0.5132 - recall_1: 0.6712 - roc_auc: 0.8696 - val_loss: 0.0382 - val_pr_auc: 0.6435 - val_precision_1: 0.5917 - val_recall_1: 0.6675 - val_roc_auc: 0.8726 - learning_rate: 1.2500e-04
# Epoch 95/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0379 - pr_auc: 0.6276 - precision_1: 0.5412 - recall_1: 0.6595 - roc_auc: 0.8648
# Epoch 95: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6232 - precision_1: 0.5275 - recall_1: 0.6626 - roc_auc: 0.8688 - val_loss: 0.0386 - val_pr_auc: 0.6449 - val_precision_1: 0.5553 - val_recall_1: 0.6921 - val_roc_auc: 0.8726 - learning_rate: 1.2500e-04
# Epoch 96/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - pr_auc: 0.6044 - precision_1: 0.5088 - recall_1: 0.6548 - roc_auc: 0.8599
# Epoch 96: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6236 - precision_1: 0.5169 - recall_1: 0.6669 - roc_auc: 0.8691 - val_loss: 0.0378 - val_pr_auc: 0.6447 - val_precision_1: 0.5079 - val_recall_1: 0.7118 - val_roc_auc: 0.8732 - learning_rate: 1.2500e-04
# Epoch 97/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0374 - pr_auc: 0.6188 - precision_1: 0.5141 - recall_1: 0.6670 - roc_auc: 0.8677
# Epoch 97: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6324 - precision_1: 0.5188 - recall_1: 0.6718 - roc_auc: 0.8702 - val_loss: 0.0376 - val_pr_auc: 0.6461 - val_precision_1: 0.5373 - val_recall_1: 0.6921 - val_roc_auc: 0.8731 - learning_rate: 1.2500e-04
# Epoch 98/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0377 - pr_auc: 0.6346 - precision_1: 0.5394 - recall_1: 0.6796 - roc_auc: 0.8723
# Epoch 98: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0373 - pr_auc: 0.6270 - precision_1: 0.5289 - recall_1: 0.6700 - roc_auc: 0.8700 - val_loss: 0.0378 - val_pr_auc: 0.6465 - val_precision_1: 0.5382 - val_recall_1: 0.6946 - val_roc_auc: 0.8731 - learning_rate: 1.2500e-04
# Epoch 99/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0360 - pr_auc: 0.6406 - precision_1: 0.5180 - recall_1: 0.6783 - roc_auc: 0.8787
# Epoch 99: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0372 - pr_auc: 0.6273 - precision_1: 0.5221 - recall_1: 0.6773 - roc_auc: 0.8704 - val_loss: 0.0378 - val_pr_auc: 0.6458 - val_precision_1: 0.5153 - val_recall_1: 0.7069 - val_roc_auc: 0.8728 - learning_rate: 1.2500e-04
# Epoch 100/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0380 - pr_auc: 0.6292 - precision_1: 0.5351 - recall_1: 0.6775 - roc_auc: 0.8689
# Epoch 100: val_pr_auc did not improve from 0.64723
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0374 - pr_auc: 0.6231 - precision_1: 0.5242 - recall_1: 0.6613 - roc_auc: 0.8693 - val_loss: 0.0391 - val_pr_auc: 0.6440 - val_precision_1: 0.5460 - val_recall_1: 0.6872 - val_roc_auc: 0.8725 - learning_rate: 1.2500e-04
# Epoch 101/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0375 - pr_auc: 0.6242 - precision_1: 0.5291 - recall_1: 0.7036 - roc_auc: 0.8729
# Epoch 101: val_pr_auc improved from 0.64723 to 0.64810, saving model to output/dna_pure_focal.keras
#
# Epoch 101: finished saving model to output/dna_pure_focal.keras
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0372 - pr_auc: 0.6306 - precision_1: 0.5207 - recall_1: 0.6829 - roc_auc: 0.8704 - val_loss: 0.0394 - val_pr_auc: 0.6481 - val_precision_1: 0.5708 - val_recall_1: 0.6749 - val_roc_auc: 0.8733 - learning_rate: 1.2500e-04
# Epoch 102/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370 - pr_auc: 0.6330 - precision_1: 0.5369 - recall_1: 0.6676 - roc_auc: 0.8743
# Epoch 102: val_pr_auc did not improve from 0.64810
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0375 - pr_auc: 0.6259 - precision_1: 0.5320 - recall_1: 0.6601 - roc_auc: 0.8689 - val_loss: 0.0369 - val_pr_auc: 0.6453 - val_precision_1: 0.5514 - val_recall_1: 0.6872 - val_roc_auc: 0.8724 - learning_rate: 1.2500e-04
# Epoch 103/200
# 305/306 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0387 - pr_auc: 0.6101 - precision_1: 0.5271 - recall_1: 0.6517 - roc_auc: 0.8615
# Epoch 103: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 103: val_pr_auc did not improve from 0.64810
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - loss: 0.0375 - pr_auc: 0.6296 - precision_1: 0.5310 - recall_1: 0.6706 - roc_auc: 0.8684 - val_loss: 0.0378 - val_pr_auc: 0.6477 - val_precision_1: 0.5338 - val_recall_1: 0.6995 - val_roc_auc: 0.8730 - learning_rate: 1.2500e-04

# %%
results = model1.evaluate(X_test, y_test, verbose=0, return_dict=True)
print(results)
# Out:
# {'loss': 0.03700753301382065, 'pr_auc': 0.6333370208740234, 'precision_1': 0.5375626087188721, 'recall_1': 0.635108470916748, 'roc_auc': 0.8741217851638794}

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['pr_auc'])
plt.plot(history.history['val_pr_auc'])
plt.title('PR-AUC')
plt.xlabel('Epoch')
plt.ylabel('PR-AUC')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.plot(history.history['roc_auc'])
plt.plot(history.history['val_roc_auc'])
plt.title('ROC-AUC')
plt.xlabel('Epoch')
plt.ylabel('ROC-AUC')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
from tensorflow.keras.models import load_model
import numpy as np

model1 = load_model("output/dna_pure_focal.keras", compile=False)
predictions = model1.predict(X_test)  
predictions = predictions.flatten()    

predicted_labels = (predictions > 0.5).astype(int)
y_true = y_test.flatten().astype(int)

accuracy = (predicted_labels == y_true).mean()
print("Test Accuracy:", accuracy)
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step
# Test Accuracy: 0.8497545008183306
